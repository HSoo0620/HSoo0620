# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.layers as layers
import matplotlib.pyplot as plt
import math
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization, Add, UpSampling3D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv3D, Input, MaxPooling3D, Dropout, concatenate, UpSampling3D, ReLU
from tensorflow.keras import backend as K

def global_normalized_cross_correlation_loss():
    def ncc(y_true, y_pred):
        """Computes the normalized cross-correlation (NCC) loss.

        Parameters
        ----------
        y_true : tf.Tensor
            The static image to which the moving image is aligned.
        y_pred : tf.Tensor
            The moving image, the same shape as the static image.

        Returns
        -------
        loss : tf.Tensor, shape ()
            Normalized cross-correlation loss between the static and the
            moving images, averaged over the batch. Range is [-1.0, 1.0].
            The best value is -1 (perfect match) and the worst is 1.

        References
        ----------
        .. [1] `Wikipedia entry for the Cross-correlation
               <https://en.wikipedia.org/wiki/Cross-correlation>`_

        """
        ndim = tf.keras.backend.ndim(y_true)-2

        # shape (N, 1, 1, C)
        y_true_mean = tf.reduce_mean(y_true, axis=range(1, ndim+1),
                                     keepdims=True)
        y_pred_mean = tf.reduce_mean(y_pred, axis=range(1, ndim+1),
                                     keepdims=True)
        plt.ylabel('Loss')

        y_true_hat = tf.math.l2_normalize(y_true-y_true_mean,
                                          axis=range(1, ndim+1))

        y_pred_hat = tf.math.l2_normalize(y_pred-y_pred_mean,
                                          axis=range(1, ndim+1))

        return -tf.reduce_mean(tf.reduce_sum(y_true_hat * y_pred_hat,
                                             axis=range(1, ndim+1)))
    return ncc


def local_normalized_cross_correlation_loss(window=(9, 9, 9), eps=1e-5):
    """
    Code borrowed from https://github.com/voxelmorph/voxelmorph/blob/legacy/src/losses.py#L28
    Paper: https://openaccess.thecvf.com/content_cvpr_2018/papers/Balakrishnan_An_Unsupervised_Learning_CVPR_2018_paper.pdf
    """
    def ncc(I, J, window=window):
        # get dimension of volume
        # assumes I, J are sized [batch_size, *vol_shape, nb_feats]
        # ndims = len(I.get_shape().as_list()) - 2
        ndims = tf.keras.backend.ndim(I)-2
        assert ndims in [1, 2, 3], "volumes should be 1 to 3 dimensions. found: %d" % ndims

        # set window size
        if window is None:
            window = [9] * ndims

        # get convolution function
        conv_fn = getattr(tf.nn, 'conv%dd' % ndims)

        # compute CC squares
        I2 = I*I
        J2 = J*J
        IJ = I*J

        # compute filters
        sum_filt = tf.ones([*window, 1, 1])
        strides = [1] * (ndims + 2)
        padding = 'SAME'

        # compute local sums via convolution
        I_sum = conv_fn(I, sum_filt, strides, padding)
        J_sum = conv_fn(J, sum_filt, strides, padding)
        I2_sum = conv_fn(I2, sum_filt, strides, padding)
        J2_sum = conv_fn(J2, sum_filt, strides, padding)
        IJ_sum = conv_fn(IJ, sum_filt, strides, padding)

        # compute cross correlation
        win_size = np.prod(window)
        u_I = I_sum/win_size
        u_J = J_sum/win_size

        cross = IJ_sum - u_J*I_sum - u_I*J_sum + u_I*u_J*win_size
        I_var = I2_sum - 2 * u_I * I_sum + u_I*u_I*win_size
        J_var = J2_sum - 2 * u_J * J_sum + u_J*u_J*win_size

        cc = cross*cross / (I_var*J_var + eps)

        # return negative cc.
        return -tf.reduce_mean(cc)
    return ncc

# vein. Portal veins are well enhanced and some enhancement of the hepatic veins is also seen on the portal venous phase. T
def gradient_loss(norm=2):
    """
    Code borrowed from https://github.com/voxelmorph/voxelmorph/blob/legacy/pytorch/losses.py#L13
    Paper: https://openaccess.thecvf.com/content_cvpr_2018/papers/Balakrishnan_An_Unsupervised_Learning_CVPR_2018_paper.pdf
    """
    def grad_loss(_, phi):
        di = tf.abs(phi[:, 1:, :, :, :] - phi[:, :-1, :, :, :])
        dj = tf.abs(phi[:, :, 1:, :, :] - phi[:, :, :-1, :, :])
        dk = tf.abs(phi[:, :, :, 1:, :] - phi[:, :, :, :-1, :])

        loss = tf.reduce_mean(di) + tf.reduce_mean(dj) + tf.reduce_mean(dk)
        if norm == 2:
            loss = tf.reduce_mean(di**2) + tf.reduce_mean(dj**2) + tf.reduce_mean(dk**2)    
        return loss
    return grad_loss

def regular_grid_3d(depth, height, width):
    """Returns a 3-D regular grid.

    Parameters
    ----------
    depth : int
        The desired depth of the grid.
    height : int
        The desired height of the grid.
    width : int
        The desired width of the grid.
    Returns
    -------
    grid : tf.Tensor, shape (D, H, W, 3)
        A 3-D regular grid, values normalized to [-1.0, 1.0]
        range.

    Notes
    -----
    Sampling using the regular grid is an identity transformation, i.e.,
    it results in the same input and output images.

    References
    ----------
    .. [1] `NumPy, "numpy.meshgrid"
        <https://numpy.org/doc/stable/reference/generated/numpy.meshgrid.html>`_
    .. [2] `NumPy, "numpy.indices"
        <https://numpy.org/doc/stable/reference/generated/numpy.indices.html>`_

    """
    i = tf.linspace(-1.0, 1.0, depth)
    j = tf.linspace(-1.0, 1.0, height)
    k = tf.linspace(-1.0, 1.0, width)

    I, J, K = tf.meshgrid(i, j, k, indexing='ij')

    grid = tf.stack([I, J, K], axis=-1)
    return grid


def grid_sample_3d(moving, grid, name=None):
    """Given a moving image and a sampling grid as input, computes the
    transformed image by sampling the moving image at locations given by
    the grid.

    Parameters
    ----------
    moving : tf.Tensor, shape (N, D, H, W, C)
        The moving image.
    grid : tf.Tensor, shape (N, D, H, W, C)
        A tensor of sampling points (x, y, z). The x, y and z values should be
        normalized to [-1.0, 1.0] range.
    name : str
        Name for the operation.

    Returns
    -------
    moved : tf.Tensor, shape (N, D, H, W, C)
        The transformed image.

    Notes
    -----
    Let M be the moving image of shape (H, W, C), T be the transformed
    image of the same shape and G be the 2D sampling grid of shape
    (H, W, 2). The value of T at a location (x, y) is T[y, x, :] =
    M[y', x', :] where [x', y'] = G[y, x, :].

    Further, [x', y'] = [x + dx, y + dy] where [dx, dy] are the
    displacements outputted by the CNN. When dx and dy are 0, the
    sampling grid G is a regular grid and the transformed image is the
    same as the moving image.

    Since the sampling point (x + dx, y + dy) can be non-integral, the
    value M[y', x'] is calculated using bi-linear interpolation.

    References
    ----------
    .. [1] `Jaderberg, Max, Karen Simonyan, and Andrew Zisserman. "Spatial
        transformer networks." Advances in neural information processing
        systems. 2015. <https://arxiv.org/abs/1506.02025>`_
    .. [2] `TensorFlow implementation of spatial transformer networks.
        <https://github.com/tensorflow/models/tree/master/research/transformer>`_
    .. [3] `Spatial Transformer Networks by Kushagra Bhatnagar
        <https://link.medium.com/0b2OrmqVO5>`_
        
    """
    nb, nd, nh, nw, nc = tf.shape(moving)
    
    i = grid[..., 0]  # shape (N, D, H, W)
    j = grid[..., 1]
    k = grid[..., 2]
    i = tf.cast(i, 'float32')
    j = tf.cast(j, 'float32')
    k = tf.cast(k, 'float32')

    # Scale i, j and k from [-1.0, 1.0] to [0, D], [0, H] and [0, W] respectively.
    i = (i + 1.0) * 0.5 * tf.cast(nd-1, 'float32')
    j = (j + 1.0) * 0.5 * tf.cast(nh-1, 'float32')
    k = (k + 1.0) * 0.5 * tf.cast(nw-1, 'float32')

    i_max = tf.cast(nd - 1, 'int32')
    j_max = tf.cast(nh - 1, 'int32')
    k_max = tf.cast(nw - 1, 'int32')
    zero = tf.constant(0, 'int32')

    # The value at (i, j, k) is a weighted average of the values at the
    # eight nearest integer locations: (i0, j0, k0), (i0, j0, k1), (i0, j1, k0),
    # (i0, j1, k1), (i1, j0, k0), (i1, j0, k1), (i1, j1, k0) and (i1, j1, k1)
    # where i0 = floor(i), i1 = ceil(i).
    i0 = tf.cast(tf.floor(i), 'int32')
    i1 = i0 + 1
    j0 = tf.cast(tf.floor(j), 'int32')
    j1 = j0 + 1
    k0 = tf.cast(tf.floor(k), 'int32')
    k1 = k0 + 1

    # Make sure indices are within the boundaries of the image.
    i0 = tf.clip_by_value(i0, zero, i_max)
    i1 = tf.clip_by_value(i1, zero, i_max)
    j0 = tf.clip_by_value(j0, zero, j_max)
    j1 = tf.clip_by_value(j1, zero, j_max)
    k0 = tf.clip_by_value(k0, zero, k_max)
    k1 = tf.clip_by_value(k1, zero, k_max)

    # Collect indices of the four corners.
    b = tf.ones_like(i0) * tf.reshape(tf.range(nb), [nb, 1, 1, 1])
    idx_a = tf.stack([b, i1, j0, k0], axis=-1)  # all front-top-left corners
    idx_b = tf.stack([b, i1, j1, k0], axis=-1)  # all front-bottom-left corners
    idx_c = tf.stack([b, i1, j0, k1], axis=-1)  # all front-top-right corners
    idx_d = tf.stack([b, i1, j1, k1], axis=-1)  # all front-bottom-right corners
    idx_e = tf.stack([b, i0, j0, k0], axis=-1)  # all back-top-left corners
    idx_f = tf.stack([b, i0, j1, k0], axis=-1)  # all back-bottom-left corners
    idx_g = tf.stack([b, i0, j0, k1], axis=-1)  # all back-top-right corners
    idx_h = tf.stack([b, i0, j1, k1], axis=-1)  # all back-bottom-right corners
    # shape (N, D, H, W, 3)

    # Collect values at the corners.
    moving_a = tf.gather_nd(moving, idx_a)  # all front-top-left values
    moving_b = tf.gather_nd(moving, idx_b)  # all front-bottom-left values
    moving_c = tf.gather_nd(moving, idx_c)  # all front-top-right values
    moving_d = tf.gather_nd(moving, idx_d)  # all front-bottom-right values
    moving_e = tf.gather_nd(moving, idx_e)  # all back-top-left values
    moving_f = tf.gather_nd(moving, idx_f)  # all back-bottom-left values
    moving_g = tf.gather_nd(moving, idx_g)  # all back-top-right values
    moving_h = tf.gather_nd(moving, idx_h)  # all back-bottom-right values
    # shape (N, D, H, W, C)

    i0_f = tf.cast(i0, 'float32')
    i1_f = tf.cast(i1, 'float32')
    j0_f = tf.cast(j0, 'float32')
    j1_f = tf.cast(j1, 'float32')
    k0_f = tf.cast(k0, 'float32')
    k1_f = tf.cast(k1, 'float32')

    # Calculate the weights.
    wa = tf.expand_dims((i - i0_f) * (j1_f - j) * (k1_f - k), axis=-1)
    wb = tf.expand_dims((i - i0_f) * (j - j0_f) * (k1_f - k), axis=-1)
    wc = tf.expand_dims((i - i0_f) * (j1_f - j) * (k - k0_f), axis=-1)
    wd = tf.expand_dims((i - i0_f) * (j - j0_f) * (k - k0_f), axis=-1)
    we = tf.expand_dims((i1_f - i) * (j1_f - j) * (k1_f - k), axis=-1)
    wf = tf.expand_dims((i1_f - i) * (j - j0_f) * (k1_f - k), axis=-1)
    wg = tf.expand_dims((i1_f - i) * (j1_f - j) * (k - k0_f), axis=-1)
    wh = tf.expand_dims((i1_f - i) * (j - j0_f) * (k - k0_f), axis=-1)

    # Calculate the weighted sum.
    moved = tf.add_n([wa * moving_a, wb * moving_b, wc * moving_c,
                      wd * moving_d, we * moving_e, wf * moving_f,
                      wg * moving_g, wh * moving_h], name=name)
    return moved

# %%
# Segmentation Model 3D Unet 
def die(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=12)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    
    return K.mean((2. * intersect / (denom + smooth)))

def die_loss(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=12)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    
    return 1 - K.mean((2. * intersect / (denom + smooth)))

def Unet3D(input_shape = (64,128,128)):
    
    out_channels = 11
    input_channels = 1 
    input_shape = input_shape + (input_channels,)
    x_in = layers.Input(shape=input_shape, name='input')
    
    # Encoder
    x0 = layers.Conv3D(16, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', name='x0')(x_in)
    x0 = layers.BatchNormalization()(x0)
    x0 = layers.ReLU()(x0)  # 16
    
    x1 = layers.Conv3D(32, kernel_size=3, strides=2, padding='same', kernel_initializer='he_normal', name='x1')(x0)
    x1 = layers.BatchNormalization()(x1)
    x1 = layers.ReLU()(x1)  # 16

    x2 = layers.Conv3D(32, kernel_size=3, strides=2, padding='same', kernel_initializer='he_normal', name='x2')(x1)
    x2 = layers.BatchNormalization()(x2)
    x2 = layers.ReLU()(x2)  # 8

    x3 = layers.Conv3D(32, kernel_size=3, strides=2, padding='same', kernel_initializer='he_normal', name='x3')(x2)
    x3 = layers.BatchNormalization()(x3)
    x3 = layers.ReLU()(x3)  # 4

    x4 = layers.Conv3D(64, kernel_size=3, strides=2, padding='same', kernel_initializer='he_normal', name='x4')(x3)
    x4 = layers.BatchNormalization()(x4)
    x4 = layers.ReLU()(x4)  # 4
    
    # decoder
    dex4 = layers.Conv3D(32, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', name='dex4')(x4)
    dex4 = layers.ReLU()(dex4)
#     dex4 = layers.UpSampling3D(size=2)(dex4)  # 4
    dex4 = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(dex4)
    dex4 = layers.concatenate([dex4, x3], axis=-1)  # 4

    dex3 = layers.Conv3D(32, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', name='dex3')(dex4)
    dex3 = layers.ReLU()(dex3)
    dex3 = layers.BatchNormalization()(dex3)
#     dex3 = layers.UpSampling3D(size=2)(dex3)  # 8
    dex3 = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(dex3)
    dex3 = layers.concatenate([dex3, x2], axis=-1)  # 8

    dex2 = layers.Conv3D(32, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', name='dex2')(dex3)
    dex2 = layers.ReLU()(dex2)
    dex2 = layers.BatchNormalization()(dex2)
#     dex2 = layers.UpSampling3D(size=2)(dex2)  # 16
    dex2 = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(dex2)
    dex2 = layers.concatenate([dex2, x1], axis=-1)  # 16

    dex1 = layers.Conv3D(16, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', name='dex1')(dex2)
    dex1 = layers.ReLU()(dex1)  # 16
    dex1 = layers.BatchNormalization()(dex1)
#     dex1 = layers.UpSampling3D(size=2)(dex1)  
    dex1 = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(dex1)
    dex1 = layers.concatenate([dex1, x0], axis=-1)
    
    dex0 = layers.Conv3D(16, kernel_size=3, strides=1, padding='same', name='dex0')(dex1)
    dex0 = layers.BatchNormalization()(dex0)
    dex0 = layers.ReLU()(dex0)
    
    x = layers.Conv3D(16, kernel_size=3, strides=1, padding='same')(dex0)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    
    segmentation = layers.Conv3D(out_channels+1, kernel_size=1, strides=1,
                                padding='same',
                                activation = 'softmax',
                                name='segmentation')(x)

    model = Model(inputs={'x_in': x_in}, outputs={'segmentation': segmentation}, name='Unet3D')

    return model

# %%
from tensorflow import keras
seg_model = Unet3D()
seg_model.summary()
seg_model.compile(optimizer=Adam(lr=0.001), 
              loss= {'segmentation': die_loss},
              metrics=[die],)

#이미 학습된 pt 가져오기 
checkpoint_path = "./seg_check_points/0803cp.ckpt"
seg_model.load_weights(checkpoint_path)
# Out:
# Model: "Unet3D"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 64, 128, 128 0
# __________________________________________________________________________________________________
# x0 (Conv3D)                     (None, 64, 128, 128, 448         input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 128, 128, 64          x0[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 64, 128, 128, 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# x1 (Conv3D)                     (None, 32, 64, 64, 3 13856       re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 64, 64, 3 128         x1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 32, 64, 64, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# x2 (Conv3D)                     (None, 16, 32, 32, 3 27680       re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 32, 32, 3 128         x2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 16, 32, 32, 3 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# x3 (Conv3D)                     (None, 8, 16, 16, 32 27680       re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 16, 16, 32 128         x3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 8, 16, 16, 32 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# x4 (Conv3D)                     (None, 4, 8, 8, 64)  55360       re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 8, 8, 64)  256         x4[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 4, 8, 8, 64)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dex4 (Conv3D)                   (None, 4, 8, 8, 32)  55328       re_lu_4[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 4, 8, 8, 32)  0           dex4[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose (Conv3DTranspo (None, 8, 16, 16, 32 27680       re_lu_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 16, 16, 64 0           conv3d_transpose[0][0]
#                                                                  re_lu_3[0][0]
# __________________________________________________________________________________________________
# dex3 (Conv3D)                   (None, 8, 16, 16, 32 55328       concatenate[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 8, 16, 16, 32 0           dex3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 16, 16, 32 128         re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_1 (Conv3DTrans (None, 16, 32, 32, 3 27680       batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 32, 32, 6 0           conv3d_transpose_1[0][0]
#                                                                  re_lu_2[0][0]
# __________________________________________________________________________________________________
# dex2 (Conv3D)                   (None, 16, 32, 32, 3 55328       concatenate_1[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 16, 32, 32, 3 0           dex2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 32, 32, 3 128         re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_2 (Conv3DTrans (None, 32, 64, 64, 3 27680       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 64, 64, 6 0           conv3d_transpose_2[0][0]
#                                                                  re_lu_1[0][0]
# __________________________________________________________________________________________________
# dex1 (Conv3D)                   (None, 32, 64, 64, 1 27664       concatenate_2[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 32, 64, 64, 1 0           dex1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 64, 64, 1 64          re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 64, 128, 128, 13856       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 128, 128, 0           conv3d_transpose_3[0][0]
#                                                                  re_lu[0][0]
# __________________________________________________________________________________________________
# dex0 (Conv3D)                   (None, 64, 128, 128, 20752       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 128, 128, 64          dex0[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 64, 128, 128, 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 64, 128, 128, 6928        re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 128, 128, 64          conv3d[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 64, 128, 128, 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# segmentation (Conv3D)           (None, 64, 128, 128, 204         re_lu_10[0][0]
# ==================================================================================================
# Total params: 444,604
# Trainable params: 444,028
# Non-trainable params: 576
# __________________________________________________________________________________________________

# %%
# Cos Sim Loss 를 위한 함수 선언

# filename1 = "./BTCV_Data/1resize/1.nii.gz"
# filename2 = "./BTCV_Data/1resize/40.nii.gz"
# data1 = nib.load(filename1).get_fdata()
# data1 = np.expand_dims((data1), axis=-1)
# data2 = nib.load(filename2).get_fdata()
# data2 = np.expand_dims((data2), axis=-1)
tf.config.run_functions_eagerly(True)
def seg_loss_():
#     def calculate_cos_sim(feat0, feat1):
# #         f1 = tf.math.l2_normalize(feat0)
# #         f2 = tf.math.l2_normalize(feat1)
#         f1 = tf.nn.l2_normalize(feat0, 1)
#         f2 = tf.nn.l2_normalize(feat1, 0)
#         s = K.sum(f1*f2)        
#         return s / (f1*f2)
    
    
#     def calculate_cos_sim(feat0, feat1):
#         norm_matrix = tf.nn.l2_normalize(feat0, 1)
#         norm_vector = tf.nn.l2_normalize(feat1, 0)
#         # multiply row i with row j using transpose
#         similarity = tf.matmul(f1, f2)
#         return similarity
    
    def calculate_cos_sim(feat0, feat1):
        cosine_loss = tf.keras.losses.CosineSimilarity(axis=1)
        
        f1 = tf.nn.l2_normalize(feat0, 1)
        f2 = tf.nn.l2_normalize(feat1, 0)
        return cosine_loss(f1, f2)
    
    
    def seg_mm(data1, data2):

        x1_model = Model(inputs=seg_model.input, outputs=seg_model.get_layer('x1').output)
    #     f1_x1 = x1_model(tf.expand_dims((data1), axis=0))
    #     f2_x1 = x1_model(tf.expand_dims((data2), axis=0))
        f1_x1 = x1_model(data1)
        f2_x1 = x1_model(data2)
        
        x2_model = Model(inputs=seg_model.input, outputs=seg_model.get_layer('x2').output)
        f1_x2 = x2_model(data1)
        f2_x2 = x2_model(data2)
        
#         x3_model = Model(inputs=seg_model.input, outputs=seg_model.get_layer('x3').output)
#         f1_x3 = x3_model(data1)
#         f2_x3 = x2_model(data2)
        #calculate_cos_sim(f1_x1, f2_x1) +  calculate_cos_sim(f1_x2, f2_x2) +  calculate_cos_sim(f1_x3, f2_x3)
        total_loss = calculate_cos_sim(f1_x1, f2_x1) +  calculate_cos_sim(f1_x2, f2_x2)
        return 1.0 - total_loss
    
    return seg_mm

# %%
def Deep_seg_loss_():

    def calculate_cos_sim(feat0, feat1):
        cosine_loss = tf.keras.losses.CosineSimilarity(axis=1)
        
        f1 = tf.nn.l2_normalize(feat0, 1)
        f2 = tf.nn.l2_normalize(feat1, 0)
        return cosine_loss(f1, f2)
    
    
    def seg_mm(data1, data2):
    
        total_loss = calculate_cos_sim(data2[0], data2[1])
        return 1.0 - total_loss
    
    return seg_mm

# %%
def gt_dice_loss_():
    
    def dice_loss(y_true, y_pred, smooth=1e-7):
        
        y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=12)[...,1:])
        y_pred_f = K.flatten(y_pred[...,1:])
        intersect = K.sum(y_true_f * y_pred_f, axis=-1)
        denom = K.sum(y_true_f + y_pred_f, axis=-1)

        return 1 - K.mean((2. * intersect / (denom + smooth)))
    
    return dice_loss

# %%
 class Dualstream(object):
    def __init__(self, input_shape=(64, 128, 128), optimizer='adam', loss=None,
                 metrics=None, loss_weights=None):
        in_channels = 1
        out_channels = 3
        input_shape = input_shape + (in_channels,)
#         self.reconstruction = Dense3DSpatialTransformer()
        
        moving = layers.Input(shape=input_shape, name='moving')
        static = layers.Input(shape=input_shape, name='static')
        
        def resblock(inputLayer,opName,channel):
            residual = inputLayer
            conv1_1 = layers.Conv3D(channel, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name= opName+'_1')(inputLayer)
            conv1_2 = layers.Conv3D(channel, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name= opName+'_2')(conv1_1)
            add1 = Add()([conv1_2, residual])
            return add1
        
        # Static과 Moving 나누어서 Encoder 진행! 
        kernel_initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=1e-5)
        
        # Static Encoder -> 8 8 16 32 32 32 
        x0_static = layers.Conv3D(8, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x0_static')(static)
        x0_static = BatchNormalization()(x0_static)
        x0_static = layers.LeakyReLU(alpha=0.2)(x0_static) # 8 
        
        x1_static = layers.Conv3D(8, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x1_static')(x0_static)
        x1_static = BatchNormalization()(x1_static)
        x1_static = layers.LeakyReLU(alpha=0.2)(x1_static)  # 8 
        x1_static = layers.Conv3D(16, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x1_static_')(x1_static)
        x1_static = resblock(x1_static, 'x1_static_1', 16)
        x1_static = resblock(x1_static, 'x1_static_2', 16) # 16

        x2_static = layers.Conv3D(16, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x2_static')(x1_static)
        x2_static = BatchNormalization()(x2_static)
        x2_static = layers.LeakyReLU(alpha=0.2)(x2_static)  # 16 
        x2_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x2_static_')(x2_static)
        x2_static = resblock(x2_static, 'x2_static_1', 32)
        x2_static = resblock(x2_static, 'x2_static_2', 32) # 32
        
        x3_static = layers.Conv3D(32, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x3_static')(x2_static)
        x3_static = BatchNormalization()(x3_static)
        x3_static = layers.LeakyReLU(alpha=0.2)(x3_static)  # 32 
        x3_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x3_static_')(x3_static)
        x3_static = resblock(x3_static, 'x3_static_1', 32)
        x3_static = resblock(x3_static, 'x3_static_2', 32) # 32

        x4_static = layers.Conv3D(32, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x4_static')(x3_static) # 32
        
        # Moving Encoder -> 8 8 16 32 32 32 
        x0_moving = layers.Conv3D(8, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x0_moving')(moving)
        x0_moving = BatchNormalization()(x0_moving)
        x0_moving = layers.LeakyReLU(alpha=0.2)(x0_moving) # 8 
        
        x1_moving = layers.Conv3D(8, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x1_moving')(x0_moving)
        x1_moving = BatchNormalization()(x1_moving)
        x1_moving = layers.LeakyReLU(alpha=0.2)(x1_moving)  # 8 
        x1_moving = layers.Conv3D(16, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x1_moving_')(x1_moving)
        x1_moving = resblock(x1_moving, 'x1_moving_1', 16)
        x1_moving = resblock(x1_moving, 'x1_moving_2', 16) # 16

        x2_moving = layers.Conv3D(16, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x2_moving')(x1_moving)
        x2_moving = BatchNormalization()(x2_moving)
        x2_moving = layers.LeakyReLU(alpha=0.2)(x2_moving)  # 16 
        x2_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x2_moving_')(x2_moving)
        x2_moving = resblock(x2_moving, 'x2_moving_1', 32)
        x2_moving = resblock(x2_moving, 'x2_moving_2', 32) # 32
        
        x3_moving = layers.Conv3D(32, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x3_moving')(x2_moving)
        x3_moving = BatchNormalization()(x3_moving)
        x3_moving = layers.LeakyReLU(alpha=0.2)(x3_moving)  # 32 
        x3_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='x3_moving_')(x3_moving)
        x3_moving = resblock(x3_moving, 'x3_moving_1', 32)
        x3_moving = resblock(x3_moving, 'x3_moving_2', 32) # 32

        x4_moving = layers.Conv3D(32, kernel_size=3, strides=2, padding='same',
                           kernel_initializer='he_normal', name='x4_moving')(x3_moving) # 32
        
        # 본격적 시작 
        concat_bottleNeck = layers.concatenate([x4_static, x4_moving], axis=4, name='concat_bottleNeck')
        
        # DVF 3
        pred4 = layers.Conv3D(3, kernel_size=3, strides=1, padding='same',
                           kernel_initializer=kernel_initializer, name='pred4')(concat_bottleNeck)
        dvf3 = UpSampling3D()(pred4)
        
#         up3_moving = UpSampling3D()(x4_moving)
#         up3_static = UpSampling3D()(x4_static)
        up3_moving = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(x4_moving)
        up3_static = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(x4_static)
    
        up3_moving = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up3_moving')(up3_moving)
        up3_moving = layers.LeakyReLU(alpha=0.1)(up3_moving) 
        up3_static = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up3_static')(up3_static)
        up3_static = layers.LeakyReLU(alpha=0.1)(up3_static)  
        
        concat3_moving = layers.concatenate([x3_moving, up3_moving], axis=4, name='concat3_moving')
        concat3_static = layers.concatenate([x3_static, up3_static], axis=4, name='concat3_static')
#         dex2_seg_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal',
#                                         name='dex2_seg_moving')(dex3_moving)
# #         dex2_seg_moving.layers.set_weights(weights_bias_dex2) 
# #         dex2_seg_moving.trainable = False
        
#         dex2_seg_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal',
#                                         name='dex2_seg_static')(dex3_static)
# #         dex2_seg_static.layers.set_weights(weights_bias_dex2) 
# #         dex2_seg_static.trainable = False

#         deep_x2_concat = layers.concatenate([dex2_seg_moving, dex2_seg_static], axis=4, name='deep_x2_concat')

#         up3_moving_rc = self.reconstruction([dex3_moving, dvf3])
        dex3_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex3_moving')(concat3_moving)
        dex3_moving = layers.LeakyReLU(alpha=0.1)(dex3_moving) 
        dex3_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex3_static')(concat3_static)
        dex3_static = layers.LeakyReLU(alpha=0.1)(dex3_static) 
        nb, nd, nh, nw, nc = tf.shape(dvf3)

        # Regular grid.
        grid = regular_grid_3d(nd, nh, nw)  # shape (D, H, W, 2)
        # print(grid.shape)
        grid = tf.expand_dims(grid, axis=0)  # shape (1, D, H, W, 2)
        multiples = tf.stack([nb, 1, 1, 1, 1])
        grid = tf.tile(grid, multiples)

        # Compute the new sampling grid.moved
        grid_new = grid + dvf3
        grid_new = tf.clip_by_value(grid_new, -1, 1)
        # print(grid_new.shape)

        # Sample the moving image using the new sampling grid.
        up3_moving_rc = grid_sample_3d(dex3_moving, grid_new, name='up3_moving_rc')
        
        concat_3_rc = layers.concatenate([up3_moving_rc, dex3_static], axis=4, name='concat_3_rc')
        
        # DVF 2
        pred3 = layers.Conv3D(3, kernel_size=3, strides=1, padding='same',
                           kernel_initializer=kernel_initializer, name='pred3')(concat_3_rc)
        dvf2 = UpSampling3D()(pred3)
        
#         up2_moving = UpSampling3D()(x3_moving)
#         up2_static = UpSampling3D()(x3_static)
        up2_moving =  layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(x3_moving)
        up2_static =  layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(x3_static)
        
        up2_moving = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up2_moving')(up2_moving)
        up2_moving = layers.LeakyReLU(alpha=0.1)(up2_moving) 
        up2_static = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up2_static')(up2_static)
        up2_static = layers.LeakyReLU(alpha=0.1)(up2_static)  
        
        concat2_moving = layers.concatenate([x2_moving, up2_moving], axis=4, name='concat2_moving')
        concat2_static = layers.concatenate([x2_static, up2_static], axis=4, name='concat2_static')
                # Deepsim x2
        #####################################!!!!!!############################################ Method1-2
        Deep_seg_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='Deep_seg_moving')(concat2_moving)
        Deep_seg_moving = layers.LeakyReLU(alpha=0.1)(Deep_seg_moving)
        
        Deep_seg_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='Deep_seg_static')(concat2_static)
        Deep_seg_static = layers.LeakyReLU(alpha=0.1)(Deep_seg_static) 
        
        deep_x2_concat = layers.concatenate([Deep_seg_moving, Deep_seg_static], axis=0, name='deep_x2_concat')
        #####################################!!!!!!############################################
        
        dex2_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex2_moving')(concat2_moving)
        dex2_moving = layers.LeakyReLU(alpha=0.1)(dex2_moving) 
        dex2_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex2_static')(concat2_static)
        dex2_static = layers.LeakyReLU(alpha=0.1)(dex2_static) 
        
#         up2_moving_rc = self.reconstruction([dex2_moving, dvf2])
        nb, nd, nh, nw, nc = tf.shape(dvf2)

        # Regular grid.
        grid = regular_grid_3d(nd, nh, nw)  # shape (D, H, W, 2)
        # print(grid.shape)
        grid = tf.expand_dims(grid, axis=0)  # shape (1, D, H, W, 2)
        multiples = tf.stack([nb, 1, 1, 1, 1])
        grid = tf.tile(grid, multiples)

        # Compute the new sampling grid.moved
        grid_new = grid + dvf2
        grid_new = tf.clip_by_value(grid_new, -1, 1)
        # print(grid_new.shape)

        # Sample the moving image using the new sampling grid.
        up2_moving_rc = grid_sample_3d(dex2_moving, grid_new, name='up2_moving_rc')
        
        concat_2_rc = layers.concatenate([up2_moving_rc, dex2_static], axis=4, name='concat_2_rc')
        
        # DFV 1 
        pred2 = layers.Conv3D(3, kernel_size=3, strides=1, padding='same',
                           kernel_initializer=kernel_initializer, name='pred2')(concat_2_rc)
        dvf1 = UpSampling3D()(pred2)
        
#         up1_moving = UpSampling3D()(x2_moving)
#         up1_static = UpSampling3D()(x2_static)
        up1_moving = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(x2_moving)
        up1_static = layers.Conv3DTranspose(32, kernel_size=3, strides=2, padding='same')(x2_static)
        
        up1_moving = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up1_moving')(up1_moving)
        up1_moving = layers.LeakyReLU(alpha=0.1)(up1_moving) 
        up1_static = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up1_static')(up1_static)
        up1_static = layers.LeakyReLU(alpha=0.1)(up1_static)  
        
        concat1_moving = layers.concatenate([x1_moving, up1_moving], axis=4, name='concat1_moving')
        concat1_static = layers.concatenate([x1_static, up1_static], axis=4, name='concat1_static')
        
        dex1_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex1_moving')(concat1_moving)
        dex1_moving = layers.LeakyReLU(alpha=0.1)(dex1_moving) 
        dex1_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex1_static')(concat1_static)
        dex1_static = layers.LeakyReLU(alpha=0.1)(dex1_static) 
        
        # up1_moving_rc = self.reconstruction([dex1_moving, dvf1])
        nb, nd, nh, nw, nc = tf.shape(dvf1)

        # Regular grid.
        grid = regular_grid_3d(nd, nh, nw)  # shape (D, H, W, 2)-
        # print(grid.shape)
        grid = tf.expand_dims(grid, axis=0)  # shape (1, D, H, W, 2)
        multiples = tf.stack([nb, 1, 1, 1, 1])
        grid = tf.tile(grid, multiples)

        # Compute the new sampling grid.moved
        grid_new = grid + dvf1
        grid_new = tf.clip_by_value(grid_new, -1, 1)
        # print(grid_new.shape)

        # Sample the moving image using the new sampling grid.
        up1_moving_rc = grid_sample_3d(dex1_moving, grid_new, name='up1_moving_rc')
        
        
        concat_1_rc = layers.concatenate([up1_moving_rc, dex1_static], axis=4, name='concat_1_rc')
        
        # DFV 0 
        pred1 = layers.Conv3D(3, kernel_size=3, strides=1, padding='same',
                           kernel_initializer=kernel_initializer, name='pred1')(concat_1_rc)
        dvf0 = UpSampling3D()(pred1)
        
#         up0_moving = UpSampling3D()(x1_moving)
#         up0_static = UpSampling3D()(x1_static)
        up0_moving = layers.Conv3DTranspose(16, kernel_size=3, strides=2, padding='same')(x1_moving)
        up0_static = layers.Conv3DTranspose(16, kernel_size=3, strides=2, padding='same')(x1_static)
        
        up0_moving = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up0_moving')(up0_moving)
        up0_moving = layers.LeakyReLU(alpha=0.1)(up0_moving) 
        up0_static = layers.Conv3D(32, kernel_size=1, strides=1, padding='same',
                           kernel_initializer='he_normal', name='up0_static')(up0_static)
        up0_static = layers.LeakyReLU(alpha=0.1)(up0_static)  
        
        concat0_moving = layers.concatenate([x0_moving, up0_moving], axis=4, name='concat0_moving')
        concat0_static = layers.concatenate([x0_static, up0_static], axis=4, name='concat0_static')
        
        dex0_moving = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex0_moving')(concat0_moving)
        dex0_moving = layers.LeakyReLU(alpha=0.1)(dex0_moving) 
        dex0_static = layers.Conv3D(32, kernel_size=3, strides=1, padding='same',
                           kernel_initializer='he_normal', name='dex0_static')(concat0_static)
        dex0_static = layers.LeakyReLU(alpha=0.1)(dex0_static) 
        
#         up0_moving_rc = self.reconstruction([dex0_moving, dvf0])
        nb, nd, nh, nw, nc = tf.shape(dvf0)

        # Regular grid.
        grid = regular_grid_3d(nd, nh, nw)  # shape (D, H, W, 2)
        # print(grid.shape)
        grid = tf.expand_dims(grid, axis=0)  # shape (1, D, H, W, 2)
        multiples = tf.stack([nb, 1, 1, 1, 1])
        grid = tf.tile(grid, multiples)

        # Compute the new sampling grid.moved
        grid_new = grid + dvf0
        grid_new = tf.clip_by_value(grid_new, -1, 1)
        # print(grid_new.shape)

        # Sample the moving image using the new sampling grid.
        up0_moving_rc = grid_sample_3d(dex0_moving, grid_new, name='up0_moving_rc')
        concat_0_rc = layers.concatenate([up0_moving_rc, dex0_static], axis=4, name='concat_0_rc')
        
        # DFV 찐 
#         pred0 = layers.Conv3D(3, kernel_size=3, strides=1, padding='same',
#                            kernel_initializer=kernel_initializer, name='pred0')(concat_0_rc)
        deformation = layers.Conv3D(3, kernel_size=3, strides=1, padding='same',
                           kernel_initializer=kernel_initializer, name='deformation')(concat_0_rc)

        nb, nd, nh, nw, nc = tf.shape(deformation)

        # Regular grid.
        grid = regular_grid_3d(nd, nh, nw)  # shape (D, H, W, 2)
        # print(grid.shape)
        grid = tf.expand_dims(grid, axis=0)  # shape (1, D, H, W, 2)
        multiples = tf.stack([nb, 1, 1, 1, 1])
        grid = tf.tile(grid, multiples)

        # Compute the new sampling grid.moved
        grid_new = grid + deformation
        grid_new = tf.clip_by_value(grid_new, -1, 1)
        # print(grid_new.shape)

        # Sample the moving image using the new sampling grid.
        moved = grid_sample_3d(moving, grid_new, name='moved')
        
        model = tf.keras.Model(inputs={'moving': moving, 'static': static},
                               outputs={'moved': moved, 'deformation': deformation, 
                                        'deep_x2_concat': deep_x2_concat}, name='Dual1')
        #                                         'pred4': pred4, 'pred3': pred3, 'pred2': pred2, 'pred1': pred1
        model.compile(optimizer=optimizer, loss=loss, metrics=metrics,
                      loss_weights=loss_weights)
        
        self.model = model

    def compile(self, optimizer='adam', loss=None, metrics=None,
                loss_weights=None):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics,
                           loss_weights=loss_weights)

    def summary(self):
        return self.model.summary()

    def fit(self, x=None, y=None, batch_size=None, epochs=1, verbose=1,
            callbacks=None, validation_split=0.0, validation_data=None,
            shuffle=True, initial_epoch=0, steps_per_epoch=None,
            validation_steps=None, validation_batch_size=None,
            validation_freq=1, max_queue_size=10, workers=1,
            use_multiprocessing=False):
        return self.model.fit(x=x, y=y, batch_size=batch_size,
                              epochs=epochs, verbose=verbose,
                              callbacks=callbacks,
                              validation_split=validation_split,
                              validation_data=validation_data, shuffle=shuffle,
                              initial_epoch=initial_epoch,
                              steps_per_epoch=steps_per_epoch,
                              validation_steps=validation_steps,
                              validation_batch_size=validation_batch_size,
                              validation_freq=validation_freq,
                              max_queue_size=max_queue_size, workers=workers,
                              use_multiprocessing=use_multiprocessing)

    def evaluate(self, x=None, y=None, batch_size=None, verbose=1,
                 steps=None, callbacks=None, max_queue_size=10, workers=1,
                 use_multiprocessing=False, return_dict=False):
        return self.model.evaluate(x=x, y=y, batch_size=batch_size,
                                   verbose=verbose, steps=steps,
                                   callbacks=callbacks,
                                   max_queue_size=max_queue_size,
                                   workers=workers,
                                   use_multiprocessing=use_multiprocessing,
                                   return_dict=return_dict)

    def predict(self, x, batch_size=None, verbose=0,
                steps=None, callbacks=None, max_queue_size=10, workers=1,
                use_multiprocessing=False):
        return self.model.predict(x=x, batch_size=batch_size,
                                  verbose=verbose, steps=steps,
                                  callbacks=callbacks,
                                  max_queue_size=max_queue_size,
                                  workers=workers,
                                  use_multiprocessing=use_multiprocessing)

    def save_weights(self, filepath, overwrite=True):
        self.model.save_weights(filepath=filepath, overwrite=overwrite, save_format=None)

    def load_weights(self, filepath):
        self.model.load_weights(filepath)
        
class RegistrationDataLoader(tf.keras.utils.Sequence):
    def __init__(self, moving, static, batch_size=8, shuffle=False):
        """Data loader object that fetches and preprocess batches of images 
        for real-time data feeding to the model.

        Currently supports only numpy arrays as input.
    
        Parameters
        ----------
        moving : ndarray, shape (N, ..., C)
            An array of all the moving images. N is the number of images.
        static : ndarray, shape (1, ..., C)
            The static image.

        """
        self.moving = moving
        self.static = static
        self.batch_size = batch_size
        self.shuffle = shuffle

        if self.shuffle:
            np.random.shuffle(self.moving)

    def __len__(self):
        return math.ceil(len(self.moving) / self.batch_size)

    def __getitem__(self, idx):
        moving = self.moving[idx * self.batch_size: (idx+1) * self.batch_size]
        static = np.repeat(self.static, repeats=moving.shape[0], axis=0)

        return {'moving': moving, 'static': static}, static  # input and output

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.moving)

# %%
batch_size = 2
epochs = 100
lr = 0.001  # learning rate
lamda = 1  # (lambda) regularization parameter
input_shape = (64, 128, 128)

# %%
# 0~1 사이로 정규화 
import nibabel as nib
import os 

# filename = "./mix_data/mixed_affine.nii.gz"
# filename2 = "./static_data_exis/7.nii.gz"
filename = "./BTCV_Data/resize_exis_stack.nii.gz"
filename2 = "./BTCV_Data/static_exis/40.nii.gz"
# filename3 = "./chaos_train_voxel/gt_resize/24.nii.gz"

data = nib.load(filename).get_fdata()
static = nib.load(filename2).get_fdata()

min_value = np.min(data)
max_value = np.max(data)

data = (data-min_value) / (max_value-min_value)
print(min_value)
print(max_value)
# Out:
# -3024.0
# 3095.0

# %%
x_train = data[:26, ...][..., None]
x_train = x_train.astype(np.float32) 
x_test = data[26:, ...][..., None]
x_test = x_test.astype(np.float32)
x_sample = data[0:1, ...].copy()  # some images to visualize results

static = (static-min_value) / (max_value-min_value)
static = static[None, ..., None]
static = static.astype(np.float32)

print('Train: ', x_train.shape) 
print('Test: ', x_test.shape)
print('Sample: ', x_sample.shape)
print('Static: ', static.shape)

train_loader = RegistrationDataLoader(x_train, static, batch_size=batch_size,
                                      shuffle=True)
test_loader = RegistrationDataLoader(x_test, static, batch_size=batch_size,
                                     shuffle=True)
sample_loader = RegistrationDataLoader(x_sample, static, shuffle=False)
# Out:
# Train:  (26, 64, 128, 128, 1)
# Test:  (4, 64, 128, 128, 1)
# Sample:  (1, 64, 128, 128)
# Static:  (1, 64, 128, 128, 1)

# %%
ncc_loss = local_normalized_cross_correlation_loss()
seg_loss = seg_loss_()
Deep_seg_loss = Deep_seg_loss_()


def total_loss(pred1, pred2):
    alpha = 0.0
    return alpha * (ncc_loss(pred1, pred2) + (1-alpha) * seg_loss(pred1, pred2)) 

grad_loss = gradient_loss()

# Map model outputs to the loss functions and loss weights
# loss_weights = {'moved': 1.0, 'deformation': lamda}
# losses = {'moved': ncc_loss, 'deformation': grad_loss}
# 'pred4': 0.1, 'pred3': 0.1, 'pred2': 0.1, 'pred1': 0.2,
# , 'pred4': grad_loss, 'pred3': grad_loss, 'pred2': grad_loss, 'pred1': grad_loss, 'pred0': grad_loss
loss_weights = {'moved': 1.0, 'deformation': lamda, 'deep_x2_concat': 1.0}
losses = {'moved': total_loss, 'deformation': grad_loss, 'deep_x2_concat': Deep_seg_loss}


# 'pred4': grad_loss, 'pred3': grad_loss, 'pred2': grad_loss, 'pred1': grad_loss, 'pred0': grad_loss

optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

model = Dualstream(input_shape=input_shape, optimizer=optimizer,
                    loss=losses, loss_weights=loss_weights)

# %%
model.summary()
# Out:
# Model: "Dual1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# moving (InputLayer)             [(None, 64, 128, 128 0
# __________________________________________________________________________________________________
# static (InputLayer)             [(None, 64, 128, 128 0
# __________________________________________________________________________________________________
# x0_moving (Conv3D)              (None, 64, 128, 128, 224         moving[0][0]
# __________________________________________________________________________________________________
# x0_static (Conv3D)              (None, 64, 128, 128, 224         static[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 128, 128, 32          x0_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 128, 128, 32          x0_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 64, 128, 128, 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 64, 128, 128, 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# x1_moving (Conv3D)              (None, 32, 64, 64, 8 1736        leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# x1_static (Conv3D)              (None, 32, 64, 64, 8 1736        leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 64, 64, 8 32          x1_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 64, 64, 8 32          x1_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 32, 64, 64, 8 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 32, 64, 64, 8 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# x1_moving_ (Conv3D)             (None, 32, 64, 64, 1 3472        leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# x1_static_ (Conv3D)             (None, 32, 64, 64, 1 3472        leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# x1_moving_1_1 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_moving_[0][0]
# __________________________________________________________________________________________________
# x1_static_1_1 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_static_[0][0]
# __________________________________________________________________________________________________
# x1_moving_1_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_moving_1_1[0][0]
# __________________________________________________________________________________________________
# x1_static_1_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_static_1_1[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 64, 64, 1 0           x1_moving_1_2[0][0]
#                                                                  x1_moving_[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 64, 64, 1 0           x1_static_1_2[0][0]
#                                                                  x1_static_[0][0]
# __________________________________________________________________________________________________
# x1_moving_2_1 (Conv3D)          (None, 32, 64, 64, 1 6928        add_18[0][0]
# __________________________________________________________________________________________________
# x1_static_2_1 (Conv3D)          (None, 32, 64, 64, 1 6928        add_12[0][0]
# __________________________________________________________________________________________________
# x1_moving_2_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_moving_2_1[0][0]
# __________________________________________________________________________________________________
# x1_static_2_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_static_2_1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 64, 64, 1 0           x1_moving_2_2[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 32, 64, 64, 1 0           x1_static_2_2[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# x2_moving (Conv3D)              (None, 16, 32, 32, 1 6928        add_19[0][0]
# __________________________________________________________________________________________________
# x2_static (Conv3D)              (None, 16, 32, 32, 1 6928        add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 32, 32, 1 64          x2_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 32, 32, 1 64          x2_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 16, 32, 32, 1 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 16, 32, 32, 1 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# x2_moving_ (Conv3D)             (None, 16, 32, 32, 3 13856       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# x2_static_ (Conv3D)             (None, 16, 32, 32, 3 13856       leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# x2_moving_1_1 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_moving_[0][0]
# __________________________________________________________________________________________________
# x2_static_1_1 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_static_[0][0]
# __________________________________________________________________________________________________
# x2_moving_1_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_moving_1_1[0][0]
# __________________________________________________________________________________________________
# x2_static_1_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_static_1_1[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 16, 32, 32, 3 0           x2_moving_1_2[0][0]
#                                                                  x2_moving_[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 32, 32, 3 0           x2_static_1_2[0][0]
#                                                                  x2_static_[0][0]
# __________________________________________________________________________________________________
# x2_moving_2_1 (Conv3D)          (None, 16, 32, 32, 3 27680       add_20[0][0]
# __________________________________________________________________________________________________
# x2_static_2_1 (Conv3D)          (None, 16, 32, 32, 3 27680       add_14[0][0]
# __________________________________________________________________________________________________
# x2_moving_2_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_moving_2_1[0][0]
# __________________________________________________________________________________________________
# x2_static_2_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_static_2_1[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 16, 32, 32, 3 0           x2_moving_2_2[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 32, 32, 3 0           x2_static_2_2[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# x3_moving (Conv3D)              (None, 8, 16, 16, 32 27680       add_21[0][0]
# __________________________________________________________________________________________________
# x3_static (Conv3D)              (None, 8, 16, 16, 32 27680       add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 16, 16, 32 128         x3_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 16, 16, 32 128         x3_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 8, 16, 16, 32 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 8, 16, 16, 32 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# x3_moving_ (Conv3D)             (None, 8, 16, 16, 32 27680       leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# x3_static_ (Conv3D)             (None, 8, 16, 16, 32 27680       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# x3_moving_1_1 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_moving_[0][0]
# __________________________________________________________________________________________________
# x3_static_1_1 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_static_[0][0]
# __________________________________________________________________________________________________
# x3_moving_1_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_moving_1_1[0][0]
# __________________________________________________________________________________________________
# x3_static_1_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_static_1_1[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 8, 16, 16, 32 0           x3_moving_1_2[0][0]
#                                                                  x3_moving_[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 16, 16, 32 0           x3_static_1_2[0][0]
#                                                                  x3_static_[0][0]
# __________________________________________________________________________________________________
# x3_moving_2_1 (Conv3D)          (None, 8, 16, 16, 32 27680       add_22[0][0]
# __________________________________________________________________________________________________
# x3_static_2_1 (Conv3D)          (None, 8, 16, 16, 32 27680       add_16[0][0]
# __________________________________________________________________________________________________
# x3_moving_2_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_moving_2_1[0][0]
# __________________________________________________________________________________________________
# x3_static_2_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_static_2_1[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 8, 16, 16, 32 0           x3_moving_2_2[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 8, 16, 16, 32 0           x3_static_2_2[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# x4_static (Conv3D)              (None, 4, 8, 8, 32)  27680       add_17[0][0]
# __________________________________________________________________________________________________
# x4_moving (Conv3D)              (None, 4, 8, 8, 32)  27680       add_23[0][0]
# __________________________________________________________________________________________________
# concat_bottleNeck (Concatenate) (None, 4, 8, 8, 64)  0           x4_static[0][0]
#                                                                  x4_moving[0][0]
# __________________________________________________________________________________________________
# pred4 (Conv3D)                  (None, 4, 8, 8, 3)   5187        concat_bottleNeck[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_4 (UpSampling3D)  (None, 8, 16, 16, 3) 0           pred4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_15 (TensorFlo [(5,)]               0           up_sampling3d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_66 (T [()]                 0           tf_op_layer_Shape_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_67 (T [()]                 0           tf_op_layer_Shape_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_68 (T [()]                 0           tf_op_layer_Shape_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_135 (TensorFlo [()]                 0           tf_op_layer_strided_slice_66[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Cast_140 (TensorFlo [()]                 0           tf_op_layer_strided_slice_67[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Cast_145 (TensorFlo [()]                 0           tf_op_layer_strided_slice_68[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sub_181 (TensorFlow [()]                 0           tf_op_layer_Cast_135[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_183 (TensorFlow [()]                 0           tf_op_layer_Cast_140[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_185 (TensorFlow [()]                 0           tf_op_layer_Cast_145[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_66 (TensorF [()]                 0           tf_op_layer_Sub_181[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GreaterEqual_15 (Te [()]                 0           tf_op_layer_Cast_135[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_68 (TensorF [()]                 0           tf_op_layer_Sub_183[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GreaterEqual_16 (Te [()]                 0           tf_op_layer_Cast_140[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_70 (TensorF [()]                 0           tf_op_layer_Sub_185[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GreaterEqual_17 (Te [()]                 0           tf_op_layer_Cast_145[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_45 (Tensor [()]                 0           tf_op_layer_GreaterEqual_15[0][0]
#                                                                  tf_op_layer_Maximum_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_48 (Tensor [()]                 0           tf_op_layer_GreaterEqual_16[0][0]
#                                                                  tf_op_layer_Maximum_68[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_51 (Tensor [()]                 0           tf_op_layer_GreaterEqual_17[0][0]
#                                                                  tf_op_layer_Maximum_70[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_138 (TensorFlo [()]                 0           tf_op_layer_SelectV2_45[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_180 (TensorFlow [()]                 0           tf_op_layer_Cast_135[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_143 (TensorFlo [()]                 0           tf_op_layer_SelectV2_48[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_182 (TensorFlow [()]                 0           tf_op_layer_Cast_140[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_148 (TensorFlo [()]                 0           tf_op_layer_SelectV2_51[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_184 (TensorFlow [()]                 0           tf_op_layer_Cast_145[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_20 (TensorFlo [(None,)]            0           tf_op_layer_Cast_138[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_65 (TensorF [()]                 0           tf_op_layer_Sub_180[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_21 (TensorFlo [(None,)]            0           tf_op_layer_Cast_143[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_67 (TensorF [()]                 0           tf_op_layer_Sub_182[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_22 (TensorFlo [(None,)]            0           tf_op_layer_Cast_148[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_69 (TensorF [()]                 0           tf_op_layer_Sub_184[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_137 (TensorFlo [()]                 0           tf_op_layer_Maximum_66[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_139 (TensorFlo [(None,)]            0           tf_op_layer_Range_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_46 (Tensor [(1,)]               0           tf_op_layer_Maximum_65[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_142 (TensorFlo [()]                 0           tf_op_layer_Maximum_68[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_144 (TensorFlo [(None,)]            0           tf_op_layer_Range_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_49 (Tensor [(1,)]               0           tf_op_layer_Maximum_67[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_147 (TensorFlo [()]                 0           tf_op_layer_Maximum_70[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_149 (TensorFlo [(None,)]            0           tf_op_layer_Range_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_52 (Tensor [(1,)]               0           tf_op_layer_Maximum_69[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_15 (TensorF [(1,)]               0           tf_op_layer_Cast_137[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_35 (TensorF [(None,)]            0           tf_op_layer_Cast_139[0][0]
#                                                                  tf_op_layer_SelectV2_46[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_16 (TensorF [(1,)]               0           tf_op_layer_Cast_142[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_36 (TensorF [(None,)]            0           tf_op_layer_Cast_144[0][0]
#                                                                  tf_op_layer_SelectV2_49[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_17 (TensorF [(1,)]               0           tf_op_layer_Cast_147[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_37 (TensorF [(None,)]            0           tf_op_layer_Cast_149[0][0]
#                                                                  tf_op_layer_SelectV2_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_185 (TensorFlow [(None,)]            0           tf_op_layer_RealDiv_15[0][0]
#                                                                  tf_op_layer_Reshape_35[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_186 (TensorFlow [(None,)]            0           tf_op_layer_RealDiv_16[0][0]
#                                                                  tf_op_layer_Reshape_36[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_187 (TensorFlow [(None,)]            0           tf_op_layer_RealDiv_17[0][0]
#                                                                  tf_op_layer_Reshape_37[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_50 (TensorFlo [(None,)]            0           tf_op_layer_Mul_185[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_51 (TensorFlo [(None,)]            0           tf_op_layer_Mul_186[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_52 (TensorFlo [(None,)]            0           tf_op_layer_Mul_187[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_15 (TensorFl [(None,)]            0           tf_op_layer_AddV2_50[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_47 (Tensor [(1,)]               0           tf_op_layer_Cast_135[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_16 (TensorFl [(None,)]            0           tf_op_layer_AddV2_51[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_50 (Tensor [(1,)]               0           tf_op_layer_Cast_140[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_17 (TensorFl [(None,)]            0           tf_op_layer_AddV2_52[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_53 (Tensor [(1,)]               0           tf_op_layer_Cast_145[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_15 (TensorFlo [(None,)]            0           tf_op_layer_concat_15[0][0]
#                                                                  tf_op_layer_SelectV2_47[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_16 (TensorFlo [(None,)]            0           tf_op_layer_concat_16[0][0]
#                                                                  tf_op_layer_SelectV2_50[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_17 (TensorFlo [(None,)]            0           tf_op_layer_concat_17[0][0]
#                                                                  tf_op_layer_SelectV2_53[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_15 (TensorFlow [()]                 0           tf_op_layer_Slice_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_16 (TensorFlow [()]                 0           tf_op_layer_Slice_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_17 (TensorFlow [()]                 0           tf_op_layer_Slice_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_packed_5 (TensorFlo [(3,)]               0           tf_op_layer_Size_15[0][0]
#                                                                  tf_op_layer_Size_16[0][0]
#                                                                  tf_op_layer_Size_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_38 (TensorF [(None, 1, 1)]       0           tf_op_layer_Slice_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Fill_10 (TensorFlow [(None, None, None)] 0           tf_op_layer_packed_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_39 (TensorF [(1, None, 1)]       0           tf_op_layer_Slice_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_40 (TensorF [(1, 1, None)]       0           tf_op_layer_Slice_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_188 (TensorFlow [(None, None, None)] 0           tf_op_layer_Reshape_38[0][0]
#                                                                  tf_op_layer_Fill_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_189 (TensorFlow [(None, None, None)] 0           tf_op_layer_Reshape_39[0][0]
#                                                                  tf_op_layer_Fill_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_190 (TensorFlow [(None, None, None)] 0           tf_op_layer_Reshape_40[0][0]
#                                                                  tf_op_layer_Fill_10[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_12 (Conv3DTran (None, 8, 16, 16, 32 27680       x4_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_45 (TensorFlo [(None, None, None,  0           tf_op_layer_Mul_188[0][0]
#                                                                  tf_op_layer_Mul_189[0][0]
#                                                                  tf_op_layer_Mul_190[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_65 (T [()]                 0           tf_op_layer_Shape_15[0][0]
# __________________________________________________________________________________________________
# up3_moving (Conv3D)             (None, 8, 16, 16, 32 1056        conv3d_transpose_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_45 (Tens [(1, None, None, Non 0           tf_op_layer_stack_45[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Pack_5 (TensorFlowO [(5,)]               0           tf_op_layer_strided_slice_65[0][0
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 8, 16, 16, 32 0           up3_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile_5 (TensorFlowO [(None, None, None,  0           tf_op_layer_ExpandDims_45[0][0]
#                                                                  tf_op_layer_Pack_5[0][0]
# __________________________________________________________________________________________________
# concat3_moving (Concatenate)    (None, 8, 16, 16, 64 0           add_23[0][0]
#                                                                  leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_53 (TensorFlo [(None, 8, 16, 16, 3 0           tf_op_layer_Tile_5[0][0]
#                                                                  up_sampling3d_4[0][0]
# __________________________________________________________________________________________________
# dex3_moving (Conv3D)            (None, 8, 16, 16, 32 55328       concat3_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_35 (TensorF [(None, 8, 16, 16, 3 0           tf_op_layer_AddV2_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 8, 16, 16, 32 0           dex3_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_71 (TensorF [(None, 8, 16, 16, 3 0           tf_op_layer_Minimum_35[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_16 (TensorFlo [(5,)]               0           leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_75 (T [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_71[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_71 (T [()]                 0           tf_op_layer_Shape_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_76 (T [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_71[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_72 (T [()]                 0           tf_op_layer_Shape_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_54 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_strided_slice_75[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sub_186 (TensorFlow [()]                 0           tf_op_layer_strided_slice_71[0][0
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_55 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_strided_slice_76[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sub_187 (TensorFlow [()]                 0           tf_op_layer_strided_slice_72[0][0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_77 (T [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_71[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_73 (T [()]                 0           tf_op_layer_Shape_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_191 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_54[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_150 (TensorFlo [()]                 0           tf_op_layer_Sub_186[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_193 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_55[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_151 (TensorFlo [()]                 0           tf_op_layer_Sub_187[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_56 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_strided_slice_77[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Sub_188 (TensorFlow [()]                 0           tf_op_layer_strided_slice_73[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Mul_192 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_Mul_191[0][0]
#                                                                  tf_op_layer_Cast_150[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_194 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_Mul_193[0][0]
#                                                                  tf_op_layer_Cast_151[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_195 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_152 (TensorFlo [()]                 0           tf_op_layer_Sub_188[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Floor_15 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_192[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Floor_16 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_194[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_196 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_Mul_195[0][0]
#                                                                  tf_op_layer_Cast_152[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_153 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Floor_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_154 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Floor_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Floor_17 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_196[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_189 (TensorFlow [()]                 0           tf_op_layer_strided_slice_71[0][0
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_58 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Cast_154[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_190 (TensorFlow [()]                 0           tf_op_layer_strided_slice_72[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Cast_155 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Floor_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_57 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Cast_153[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_36 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Cast_153[0][0]
#                                                                  tf_op_layer_Sub_189[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_39 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_58[0][0]
#                                                                  tf_op_layer_Sub_190[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_59 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Cast_155[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_191 (TensorFlow [()]                 0           tf_op_layer_strided_slice_73[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_37 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_57[0][0]
#                                                                  tf_op_layer_Sub_189[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_38 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Cast_154[0][0]
#                                                                  tf_op_layer_Sub_190[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_72 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_36[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_75 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_39[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_41 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_59[0][0]
#                                                                  tf_op_layer_Sub_191[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_70 (T [()]                 0           tf_op_layer_Shape_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_73 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_37[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_74 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_38[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_40 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Cast_155[0][0]
#                                                                  tf_op_layer_Sub_191[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_156 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_72[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_159 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_75[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_77 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_41[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_17 (TensorFlo [(4,)]               0           tf_op_layer_Maximum_72[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_23 (TensorFlo [(None,)]            0           tf_op_layer_strided_slice_70[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_41/shape (T [(4,)]               0           tf_op_layer_strided_slice_70[0][0
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_76 (TensorF [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_40[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_158 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_74[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_157 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_73[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_192 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_Mul_192[0][0]
#                                                                  tf_op_layer_Cast_156[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_193 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_Cast_159[0][0]
#                                                                  tf_op_layer_Mul_194[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_161 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_77[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Fill_11 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_Shape_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_41 (TensorF [(None, 1, 1, 1)]    0           tf_op_layer_Range_23[0][0]
# ...
#                                                                  tf_op_layer_Sub_355[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_356 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_344[0][0]
#                                                                  tf_op_layer_Cast_268[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_360 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Sub_357[0][0]
#                                                                  tf_op_layer_Sub_358[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_359 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_344[0][0]
#                                                                  tf_op_layer_Cast_268[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_347 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_346[0][0]
#                                                                  tf_op_layer_Sub_338[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_82 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_125[0][0]
#                                                                  tf_op_layer_Maximum_126[0][0]
#                                                                  tf_op_layer_Maximum_128[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_349 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_348[0][0]
#                                                                  tf_op_layer_Sub_341[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_83 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_125[0][0]
#                                                                  tf_op_layer_Maximum_127[0][0]
#                                                                  tf_op_layer_Maximum_128[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_351 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_350[0][0]
#                                                                  tf_op_layer_Sub_344[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_84 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_125[0][0]
#                                                                  tf_op_layer_Maximum_126[0][0]
#                                                                  tf_op_layer_Maximum_129[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_353 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_352[0][0]
#                                                                  tf_op_layer_Sub_347[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_85 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_125[0][0]
#                                                                  tf_op_layer_Maximum_127[0][0]
#                                                                  tf_op_layer_Maximum_129[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_355 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_354[0][0]
#                                                                  tf_op_layer_Sub_350[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_86 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_124[0][0]
#                                                                  tf_op_layer_Maximum_126[0][0]
#                                                                  tf_op_layer_Maximum_128[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_357 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_356[0][0]
#                                                                  tf_op_layer_Sub_353[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_87 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_124[0][0]
#                                                                  tf_op_layer_Maximum_127[0][0]
#                                                                  tf_op_layer_Maximum_128[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_359 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_358[0][0]
#                                                                  tf_op_layer_Sub_356[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_88 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_124[0][0]
#                                                                  tf_op_layer_Maximum_126[0][0]
#                                                                  tf_op_layer_Maximum_129[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_361 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_360[0][0]
#                                                                  tf_op_layer_Sub_359[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_89 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_345[0][0]
#                                                                  tf_op_layer_Maximum_124[0][0]
#                                                                  tf_op_layer_Maximum_127[0][0]
#                                                                  tf_op_layer_Maximum_129[0][0]
# __________________________________________________________________________________________________
# Deep_seg_moving (Conv3D)        (None, 16, 32, 32, 3 55328       concat2_moving[0][0]
# __________________________________________________________________________________________________
# Deep_seg_static (Conv3D)        (None, 16, 32, 32, 3 55328       concat2_static[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_82 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_347[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_72 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_82[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_83 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_349[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_73 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_83[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_84 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_351[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_74 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_84[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_85 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_353[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_75 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_85[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_86 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_355[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_76 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_86[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_87 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_357[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_77 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_87[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_88 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_359[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_78 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_88[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_89 (Tens [(None, 64, 128, 128 0           tf_op_layer_Mul_361[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_79 (Tensor [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_89[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 16, 32, 32, 3 0           Deep_seg_moving[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 16, 32, 32, 3 0           Deep_seg_static[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_362 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_82[0][0]
#                                                                  tf_op_layer_GatherNd_72[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_363 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_83[0][0]
#                                                                  tf_op_layer_GatherNd_73[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_364 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_84[0][0]
#                                                                  tf_op_layer_GatherNd_74[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_365 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_85[0][0]
#                                                                  tf_op_layer_GatherNd_75[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_366 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_86[0][0]
#                                                                  tf_op_layer_GatherNd_76[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_367 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_87[0][0]
#                                                                  tf_op_layer_GatherNd_77[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_368 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_88[0][0]
#                                                                  tf_op_layer_GatherNd_78[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_369 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_89[0][0]
#                                                                  tf_op_layer_GatherNd_79[0][0]
# __________________________________________________________________________________________________
# deep_x2_concat (Concatenate)    (None, 16, 32, 32, 3 0           leaky_re_lu_40[0][0]
#                                                                  leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_moved_1 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_362[0][0]
#                                                                  tf_op_layer_Mul_363[0][0]
#                                                                  tf_op_layer_Mul_364[0][0]
#                                                                  tf_op_layer_Mul_365[0][0]
#                                                                  tf_op_layer_Mul_366[0][0]
#                                                                  tf_op_layer_Mul_367[0][0]
#                                                                  tf_op_layer_Mul_368[0][0]
#                                                                  tf_op_layer_Mul_369[0][0]
# ==================================================================================================
# Total params: 1,414,783
# Trainable params: 1,414,527
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
import numpy
dex2 = seg_model.get_layer('dex3')
# weights_bias_dex2 = dex2.get_weights()
weights_bias_dex2 = dex2.get_weights()


# weights_bias_dex2 = numpy.array(weights_bias_dex2)
# print(weights_bias_dex2.shape)

# %%
# dex2_seg_moving = model.model.get_layer('dex2_seg_moving')
# dex2_seg_moving.set_weights(weights_bias_dex2)
# dex2_seg_moving.trainable = False

# dex2_seg_static = model.model.get_layer('dex2_seg_static')
# dex2_seg_static.set_weights(weights_bias_dex2) 
# dex2_seg_static.trainable = False

dex2_seg_moving = model.model.get_layer('Deep_seg_moving')
dex2_seg_moving.set_weights(weights_bias_dex2)
dex2_seg_moving.trainable = False

dex2_seg_static = model.model.get_layer('Deep_seg_static')
dex2_seg_static.set_weights(weights_bias_dex2) 

dex2_seg_static.trainable = False

# %%
import tensorflow

early_stop = tensorflow.keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=600, restore_best_weights=True) 
checkpoint_path = "./check_points/0811_1cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                   save_weights_only=True,
                                   verbose=1)# Train the model with the new callback

# %%
hist = model.fit(train_loader, epochs=epochs, validation_data=test_loader, callbacks=[cp_callback, early_stop])
# Out:
# Epoch 1/100
# 13/13 [==============================] - ETA: 0s - loss: 1.1437 - deep_x2_concat_loss: 1.1155 - deformation_loss: 0.0282 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00001: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 24s 2s/step - loss: 1.1437 - deep_x2_concat_loss: 1.1155 - deformation_loss: 0.0282 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8400 - val_deep_x2_concat_loss: 1.8393 - val_deformation_loss: 6.8491e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 2/100
# 13/13 [==============================] - ETA: 0s - loss: 1.0602 - deep_x2_concat_loss: 1.0580 - deformation_loss: 0.0022 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00002: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 26s 2s/step - loss: 1.0602 - deep_x2_concat_loss: 1.0580 - deformation_loss: 0.0022 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8054 - val_deep_x2_concat_loss: 1.8053 - val_deformation_loss: 1.1989e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 3/100
# 13/13 [==============================] - ETA: 0s - loss: 0.9529 - deep_x2_concat_loss: 0.9523 - deformation_loss: 5.6485e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00003: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 26s 2s/step - loss: 0.9529 - deep_x2_concat_loss: 0.9523 - deformation_loss: 5.6485e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.1836 - val_deep_x2_concat_loss: 1.1835 - val_deformation_loss: 6.0911e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 4/100
# 13/13 [==============================] - ETA: 0s - loss: 0.9260 - deep_x2_concat_loss: 0.9257 - deformation_loss: 3.2780e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00004: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 26s 2s/step - loss: 0.9260 - deep_x2_concat_loss: 0.9257 - deformation_loss: 3.2780e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.1412 - val_deep_x2_concat_loss: 1.1412 - val_deformation_loss: 4.4193e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 5/100
# 13/13 [==============================] - ETA: 0s - loss: 0.9377 - deep_x2_concat_loss: 0.9375 - deformation_loss: 2.3944e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00005: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.9377 - deep_x2_concat_loss: 0.9375 - deformation_loss: 2.3944e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.1058 - val_deep_x2_concat_loss: 1.1058 - val_deformation_loss: 3.3034e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 6/100
# 13/13 [==============================] - ETA: 0s - loss: 1.0015 - deep_x2_concat_loss: 1.0013 - deformation_loss: 1.9260e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00006: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 1.0015 - deep_x2_concat_loss: 1.0013 - deformation_loss: 1.9260e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.0600 - val_deep_x2_concat_loss: 1.0600 - val_deformation_loss: 2.5377e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 7/100
# 13/13 [==============================] - ETA: 0s - loss: 0.9028 - deep_x2_concat_loss: 0.9026 - deformation_loss: 1.6315e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00007: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.9028 - deep_x2_concat_loss: 0.9026 - deformation_loss: 1.6315e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.4521 - val_deep_x2_concat_loss: 1.4521 - val_deformation_loss: 2.1135e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 8/100
# 13/13 [==============================] - ETA: 0s - loss: 0.8982 - deep_x2_concat_loss: 0.8981 - deformation_loss: 1.4228e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00008: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.8982 - deep_x2_concat_loss: 0.8981 - deformation_loss: 1.4228e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.4538 - val_deep_x2_concat_loss: 1.4538 - val_deformation_loss: 2.0324e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 9/100
# 13/13 [==============================] - ETA: 0s - loss: 0.7851 - deep_x2_concat_loss: 0.7849 - deformation_loss: 1.2628e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00009: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.7851 - deep_x2_concat_loss: 0.7849 - deformation_loss: 1.2628e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.0552 - val_deep_x2_concat_loss: 1.0551 - val_deformation_loss: 3.0366e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 10/100
# 13/13 [==============================] - ETA: 0s - loss: 1.0865 - deep_x2_concat_loss: 1.0864 - deformation_loss: 1.1339e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00010: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 1.0865 - deep_x2_concat_loss: 1.0864 - deformation_loss: 1.1339e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.7954 - val_deep_x2_concat_loss: 0.7953 - val_deformation_loss: 3.3876e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 11/100
# 13/13 [==============================] - ETA: 0s - loss: 0.8093 - deep_x2_concat_loss: 0.8092 - deformation_loss: 1.0271e-04 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00011: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 24s 2s/step - loss: 0.8093 - deep_x2_concat_loss: 0.8092 - deformation_loss: 1.0271e-04 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.6266 - val_deep_x2_concat_loss: 1.6266 - val_deformation_loss: 3.1756e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 12/100
# 13/13 [==============================] - ETA: 0s - loss: 0.8367 - deep_x2_concat_loss: 0.8366 - deformation_loss: 9.3677e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00012: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.8367 - deep_x2_concat_loss: 0.8366 - deformation_loss: 9.3677e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.4714 - val_deep_x2_concat_loss: 0.4714 - val_deformation_loss: 9.2531e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 13/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5950 - deep_x2_concat_loss: 0.5950 - deformation_loss: 8.5930e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00013: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 26s 2s/step - loss: 0.5950 - deep_x2_concat_loss: 0.5950 - deformation_loss: 8.5930e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.9019 - val_deep_x2_concat_loss: 0.9017 - val_deformation_loss: 2.0812e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 14/100
# 13/13 [==============================] - ETA: 0s - loss: 0.7859 - deep_x2_concat_loss: 0.7858 - deformation_loss: 7.9226e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00014: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.7859 - deep_x2_concat_loss: 0.7858 - deformation_loss: 7.9226e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.7741 - val_deep_x2_concat_loss: 1.7741 - val_deformation_loss: 5.6389e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 15/100
# 13/13 [==============================] - ETA: 0s - loss: 0.9986 - deep_x2_concat_loss: 0.9985 - deformation_loss: 7.3378e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00015: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.9986 - deep_x2_concat_loss: 0.9985 - deformation_loss: 7.3378e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.7371 - val_deep_x2_concat_loss: 0.7370 - val_deformation_loss: 1.5341e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 16/100
# 13/13 [==============================] - ETA: 0s - loss: 0.8519 - deep_x2_concat_loss: 0.8518 - deformation_loss: 6.8240e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00016: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.8519 - deep_x2_concat_loss: 0.8518 - deformation_loss: 6.8240e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.5467 - val_deep_x2_concat_loss: 1.5465 - val_deformation_loss: 1.3927e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 17/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5782 - deep_x2_concat_loss: 0.5782 - deformation_loss: 6.3691e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00017: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.5782 - deep_x2_concat_loss: 0.5782 - deformation_loss: 6.3691e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.8666 - val_deep_x2_concat_loss: 0.8663 - val_deformation_loss: 2.6909e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 18/100
# 13/13 [==============================] - ETA: 0s - loss: 0.7707 - deep_x2_concat_loss: 0.7706 - deformation_loss: 5.9636e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00018: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.7707 - deep_x2_concat_loss: 0.7706 - deformation_loss: 5.9636e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8617 - val_deep_x2_concat_loss: 1.8616 - val_deformation_loss: 1.4430e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 19/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6271 - deep_x2_concat_loss: 0.6271 - deformation_loss: 5.6004e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00019: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.6271 - deep_x2_concat_loss: 0.6271 - deformation_loss: 5.6004e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9011 - val_deep_x2_concat_loss: 1.9007 - val_deformation_loss: 3.8650e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 20/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6822 - deep_x2_concat_loss: 0.6821 - deformation_loss: 5.2733e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00020: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.6822 - deep_x2_concat_loss: 0.6821 - deformation_loss: 5.2733e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.1197 - val_deep_x2_concat_loss: 0.1194 - val_deformation_loss: 3.4539e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 21/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6705 - deep_x2_concat_loss: 0.6705 - deformation_loss: 4.9776e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00021: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 26s 2s/step - loss: 0.6705 - deep_x2_concat_loss: 0.6705 - deformation_loss: 4.9776e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0918 - val_deep_x2_concat_loss: 0.0897 - val_deformation_loss: 0.0021 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 22/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4170 - deep_x2_concat_loss: 0.4169 - deformation_loss: 4.7087e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00022: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4170 - deep_x2_concat_loss: 0.4169 - deformation_loss: 4.7087e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8330 - val_deep_x2_concat_loss: 1.8306 - val_deformation_loss: 0.0024 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 23/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5727 - deep_x2_concat_loss: 0.5727 - deformation_loss: 4.4635e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00023: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.5727 - deep_x2_concat_loss: 0.5727 - deformation_loss: 4.4635e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.5498 - val_deep_x2_concat_loss: 0.5498 - val_deformation_loss: 2.4625e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 24/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4190 - deep_x2_concat_loss: 0.4189 - deformation_loss: 4.2389e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00024: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4190 - deep_x2_concat_loss: 0.4189 - deformation_loss: 4.2389e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.4263 - val_deep_x2_concat_loss: 0.4263 - val_deformation_loss: 2.4543e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 25/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5466 - deep_x2_concat_loss: 0.5466 - deformation_loss: 4.0326e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00025: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.5466 - deep_x2_concat_loss: 0.5466 - deformation_loss: 4.0326e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9202 - val_deep_x2_concat_loss: 1.9201 - val_deformation_loss: 2.6665e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 26/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2828 - deep_x2_concat_loss: 0.2828 - deformation_loss: 3.8424e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00026: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2828 - deep_x2_concat_loss: 0.2828 - deformation_loss: 3.8424e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9015 - val_deep_x2_concat_loss: 1.9015 - val_deformation_loss: 2.4651e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 27/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2907 - deep_x2_concat_loss: 0.2907 - deformation_loss: 3.6667e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00027: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2907 - deep_x2_concat_loss: 0.2907 - deformation_loss: 3.6667e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8344 - val_deep_x2_concat_loss: 1.8343 - val_deformation_loss: 2.7850e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 28/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3643 - deep_x2_concat_loss: 0.3642 - deformation_loss: 3.5039e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00028: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 27s 2s/step - loss: 0.3643 - deep_x2_concat_loss: 0.3642 - deformation_loss: 3.5039e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0744 - val_deep_x2_concat_loss: 0.0743 - val_deformation_loss: 5.4387e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 29/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5319 - deep_x2_concat_loss: 0.5318 - deformation_loss: 3.3526e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00029: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 38s 3s/step - loss: 0.5319 - deep_x2_concat_loss: 0.5318 - deformation_loss: 3.3526e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0808 - val_deep_x2_concat_loss: 0.0808 - val_deformation_loss: 5.6338e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 30/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5069 - deep_x2_concat_loss: 0.5068 - deformation_loss: 3.2118e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00030: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 40s 3s/step - loss: 0.5069 - deep_x2_concat_loss: 0.5068 - deformation_loss: 3.2118e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9107 - val_deep_x2_concat_loss: 1.9104 - val_deformation_loss: 2.9137e-04 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 31/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3320 - deep_x2_concat_loss: 0.3320 - deformation_loss: 3.0804e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00031: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 44s 3s/step - loss: 0.3320 - deep_x2_concat_loss: 0.3320 - deformation_loss: 3.0804e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0462 - val_deep_x2_concat_loss: 0.0445 - val_deformation_loss: 0.0016 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 32/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3450 - deep_x2_concat_loss: 0.3450 - deformation_loss: 2.9575e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00032: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 34s 3s/step - loss: 0.3450 - deep_x2_concat_loss: 0.3450 - deformation_loss: 2.9575e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9592 - val_deep_x2_concat_loss: 1.9529 - val_deformation_loss: 0.0064 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 33/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4606 - deep_x2_concat_loss: 0.4606 - deformation_loss: 2.8424e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00033: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 30s 2s/step - loss: 0.4606 - deep_x2_concat_loss: 0.4606 - deformation_loss: 2.8424e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0510 - val_deep_x2_concat_loss: 0.0497 - val_deformation_loss: 0.0013 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 34/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5559 - deep_x2_concat_loss: 0.5558 - deformation_loss: 2.7345e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00034: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 27s 2s/step - loss: 0.5559 - deep_x2_concat_loss: 0.5558 - deformation_loss: 2.7345e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8171 - val_deep_x2_concat_loss: 1.8159 - val_deformation_loss: 0.0012 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 35/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3669 - deep_x2_concat_loss: 0.3669 - deformation_loss: 2.6330e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00035: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 26s 2s/step - loss: 0.3669 - deep_x2_concat_loss: 0.3669 - deformation_loss: 2.6330e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.2487 - val_deep_x2_concat_loss: 1.2487 - val_deformation_loss: 2.6394e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 36/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6822 - deep_x2_concat_loss: 0.6822 - deformation_loss: 2.5375e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00036: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.6822 - deep_x2_concat_loss: 0.6822 - deformation_loss: 2.5375e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.7435 - val_deep_x2_concat_loss: 1.7435 - val_deformation_loss: 1.8348e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 37/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5925 - deep_x2_concat_loss: 0.5925 - deformation_loss: 2.4475e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00037: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.5925 - deep_x2_concat_loss: 0.5925 - deformation_loss: 2.4475e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0672 - val_deep_x2_concat_loss: 0.0672 - val_deformation_loss: 1.8061e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 38/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4118 - deep_x2_concat_loss: 0.4117 - deformation_loss: 2.3625e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00038: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4118 - deep_x2_concat_loss: 0.4117 - deformation_loss: 2.3625e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0477 - val_deep_x2_concat_loss: 0.0476 - val_deformation_loss: 1.7791e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 39/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3873 - deep_x2_concat_loss: 0.3873 - deformation_loss: 2.2822e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00039: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.3873 - deep_x2_concat_loss: 0.3873 - deformation_loss: 2.2822e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0999 - val_deep_x2_concat_loss: 0.0999 - val_deformation_loss: 1.7536e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 40/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4653 - deep_x2_concat_loss: 0.4653 - deformation_loss: 2.2062e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00040: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4653 - deep_x2_concat_loss: 0.4653 - deformation_loss: 2.2062e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8161 - val_deep_x2_concat_loss: 1.8160 - val_deformation_loss: 1.7296e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 41/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3414 - deep_x2_concat_loss: 0.3413 - deformation_loss: 2.1342e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00041: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.3414 - deep_x2_concat_loss: 0.3413 - deformation_loss: 2.1342e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0547 - val_deep_x2_concat_loss: 0.0547 - val_deformation_loss: 1.7063e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 42/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2861 - deep_x2_concat_loss: 0.2861 - deformation_loss: 2.0658e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00042: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2861 - deep_x2_concat_loss: 0.2861 - deformation_loss: 2.0658e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0698 - val_deep_x2_concat_loss: 0.0698 - val_deformation_loss: 1.6833e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 43/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4457 - deep_x2_concat_loss: 0.4457 - deformation_loss: 2.0009e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00043: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4457 - deep_x2_concat_loss: 0.4457 - deformation_loss: 2.0009e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0469 - val_deep_x2_concat_loss: 0.0469 - val_deformation_loss: 1.6606e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 44/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3814 - deep_x2_concat_loss: 0.3813 - deformation_loss: 1.9392e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00044: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.3814 - deep_x2_concat_loss: 0.3813 - deformation_loss: 1.9392e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.6141 - val_deep_x2_concat_loss: 1.6141 - val_deformation_loss: 1.6379e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 45/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6057 - deep_x2_concat_loss: 0.6057 - deformation_loss: 1.8804e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00045: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.6057 - deep_x2_concat_loss: 0.6057 - deformation_loss: 1.8804e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.0437 - val_deep_x2_concat_loss: 0.0437 - val_deformation_loss: 1.6152e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 46/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2302 - deep_x2_concat_loss: 0.2302 - deformation_loss: 1.8243e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00046: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2302 - deep_x2_concat_loss: 0.2302 - deformation_loss: 1.8243e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9561 - val_deep_x2_concat_loss: 1.9561 - val_deformation_loss: 1.5922e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 47/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4140 - deep_x2_concat_loss: 0.4140 - deformation_loss: 1.7709e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00047: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4140 - deep_x2_concat_loss: 0.4140 - deformation_loss: 1.7709e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.6463 - val_deep_x2_concat_loss: 1.6463 - val_deformation_loss: 1.5690e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 48/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1726 - deep_x2_concat_loss: 0.1725 - deformation_loss: 1.7198e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00048: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.1726 - deep_x2_concat_loss: 0.1725 - deformation_loss: 1.7198e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.1964 - val_deep_x2_concat_loss: 0.1964 - val_deformation_loss: 1.5453e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 49/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5336 - deep_x2_concat_loss: 0.5336 - deformation_loss: 1.6710e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00049: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.5336 - deep_x2_concat_loss: 0.5336 - deformation_loss: 1.6710e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.3193 - val_deep_x2_concat_loss: 1.3193 - val_deformation_loss: 1.5212e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 50/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6187 - deep_x2_concat_loss: 0.6187 - deformation_loss: 1.6243e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00050: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.6187 - deep_x2_concat_loss: 0.6187 - deformation_loss: 1.6243e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.1926 - val_deep_x2_concat_loss: 0.1926 - val_deformation_loss: 1.4968e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 51/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2101 - deep_x2_concat_loss: 0.2100 - deformation_loss: 1.5796e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00051: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2101 - deep_x2_concat_loss: 0.2100 - deformation_loss: 1.5796e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.1102 - val_deep_x2_concat_loss: 0.1102 - val_deformation_loss: 1.4720e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 52/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3537 - deep_x2_concat_loss: 0.3537 - deformation_loss: 1.5368e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00052: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.3537 - deep_x2_concat_loss: 0.3537 - deformation_loss: 1.5368e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.3417 - val_deep_x2_concat_loss: 0.3417 - val_deformation_loss: 1.4468e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 53/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6078 - deep_x2_concat_loss: 0.6078 - deformation_loss: 1.4958e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00053: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.6078 - deep_x2_concat_loss: 0.6078 - deformation_loss: 1.4958e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9427 - val_deep_x2_concat_loss: 1.9427 - val_deformation_loss: 1.4212e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 54/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5990 - deep_x2_concat_loss: 0.5990 - deformation_loss: 1.4564e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00054: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.5990 - deep_x2_concat_loss: 0.5990 - deformation_loss: 1.4564e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9358 - val_deep_x2_concat_loss: 1.9358 - val_deformation_loss: 1.3953e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 55/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4340 - deep_x2_concat_loss: 0.4339 - deformation_loss: 1.4186e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00055: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4340 - deep_x2_concat_loss: 0.4339 - deformation_loss: 1.4186e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9355 - val_deep_x2_concat_loss: 1.9355 - val_deformation_loss: 1.3692e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 56/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4997 - deep_x2_concat_loss: 0.4997 - deformation_loss: 1.3823e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00056: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4997 - deep_x2_concat_loss: 0.4997 - deformation_loss: 1.3823e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9385 - val_deep_x2_concat_loss: 1.9385 - val_deformation_loss: 1.3429e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 57/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5818 - deep_x2_concat_loss: 0.5818 - deformation_loss: 1.3474e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00057: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.5818 - deep_x2_concat_loss: 0.5818 - deformation_loss: 1.3474e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.9269 - val_deep_x2_concat_loss: 1.9269 - val_deformation_loss: 1.3166e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 58/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4608 - deep_x2_concat_loss: 0.4608 - deformation_loss: 1.3139e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00058: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.4608 - deep_x2_concat_loss: 0.4608 - deformation_loss: 1.3139e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.4033 - val_deep_x2_concat_loss: 0.4033 - val_deformation_loss: 1.2905e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 59/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2483 - deep_x2_concat_loss: 0.2482 - deformation_loss: 1.2815e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00059: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2483 - deep_x2_concat_loss: 0.2482 - deformation_loss: 1.2815e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.2352 - val_deep_x2_concat_loss: 0.2351 - val_deformation_loss: 1.2644e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 60/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1959 - deep_x2_concat_loss: 0.1959 - deformation_loss: 1.2504e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00060: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.1959 - deep_x2_concat_loss: 0.1959 - deformation_loss: 1.2504e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.6585 - val_deep_x2_concat_loss: 0.6585 - val_deformation_loss: 1.2387e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 61/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2530 - deep_x2_concat_loss: 0.2530 - deformation_loss: 1.2204e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00061: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2530 - deep_x2_concat_loss: 0.2530 - deformation_loss: 1.2204e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.2509 - val_deep_x2_concat_loss: 0.2509 - val_deformation_loss: 1.2132e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 62/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3142 - deep_x2_concat_loss: 0.3142 - deformation_loss: 1.1915e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00062: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 26s 2s/step - loss: 0.3142 - deep_x2_concat_loss: 0.3142 - deformation_loss: 1.1915e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 0.9689 - val_deep_x2_concat_loss: 0.9689 - val_deformation_loss: 1.1881e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 63/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2821 - deep_x2_concat_loss: 0.2820 - deformation_loss: 1.1636e-05 - tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 00063: saving model to ./check_points/0811_1cp.ckpt
# 13/13 [==============================] - 25s 2s/step - loss: 0.2821 - deep_x2_concat_loss: 0.2820 - deformation_loss: 1.1636e-05 - tf_op_layer_moved_1_loss: 0.0000e+00 - val_loss: 1.8850 - val_deep_x2_concat_loss: 1.8850 - val_deformation_loss: 1.1634e-05 - val_tf_op_layer_moved_1_loss: 0.0000e+00
# Epoch 64/100
#  1/13 [=>............................] - ETA: 0s - loss: 1.7573 - deep_x2_concat_loss: 1.7573 - deformation_loss: 1.1490e-05 - tf_op_layer_moved_1_loss: 0.0000e+00

# %%
model.summary()

# %%
plt.plot(hist.history['loss'], color='red', label='Train')
plt.plot(hist.history['val_loss'], color='blue', label='Test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper right")
plt.title('Loss vs. Epochs')
plt.show()

# %%
checkpoint_path = "./check_points/0809_2cp.ckpt"
model.save_weights(checkpoint_path)

# %%
checkpoint_path = "./check_points/0809_2cp.ckpt"
model.load_weights(checkpoint_path)

# %%
# ## 간단하게 결과 보기 위한 코드 ##
# output = model.predict(sample_loader)
# moved = output['moved']
# deformation = output['deformation']

# %%
## 간단하게 결과 보기 위한 코드 ##
output = model.predict(sample_loader)
moved = output['moved']
deformation = output['deformation']

# moved = moved * max_value
print(moved.shape)
a = moved[0]
b = deformation[0]

print(a.shape)
a = a.swapaxes(0,2) 
b = b.swapaxes(0,2) 
print(a.shape)

a = nib.Nifti1Image(a,None) 
b = nib.Nifti1Image(b,None)

nib.save(a,'BTCV_Data/moved_0809_3.nii.gz')
nib.save(b,'BTCV_Data/deformation_0809_3.nii.gz')
# Out:
# (1, 64, 128, 128, 1)
# (64, 128, 128, 1)
# (128, 128, 64, 1)

# %%
f1model = Model(inputs=model.model.input, outputs=model.model.get_layer('tf_op_layer_up0_moving_rc_5').output)
pred2 = f1model.predict(sample_loader)

a = pred2[0]
print(a.shape)
a = a.swapaxes(0,2) 
print(a.shape)

a = nib.Nifti1Image(a,None) 

nib.save(a,'BTCV_Data/tf_op_layer_up0_moving_rc_5.nii.gz')
# Out:
# (64, 128, 128, 32)
# (128, 128, 64, 32)

# %%
model.summary()
# Out:
# Model: "Dual1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# moving (InputLayer)             [(None, 64, 128, 128 0
# __________________________________________________________________________________________________
# static (InputLayer)             [(None, 64, 128, 128 0
# __________________________________________________________________________________________________
# x0_moving (Conv3D)              (None, 64, 128, 128, 224         moving[0][0]
# __________________________________________________________________________________________________
# x0_static (Conv3D)              (None, 64, 128, 128, 224         static[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 64, 128, 128, 32          x0_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 64, 128, 128, 32          x0_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_148 (LeakyReLU)     (None, 64, 128, 128, 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_144 (LeakyReLU)     (None, 64, 128, 128, 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# x1_moving (Conv3D)              (None, 32, 64, 64, 8 1736        leaky_re_lu_148[0][0]
# __________________________________________________________________________________________________
# x1_static (Conv3D)              (None, 32, 64, 64, 8 1736        leaky_re_lu_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 32, 64, 64, 8 32          x1_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 64, 64, 8 32          x1_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_149 (LeakyReLU)     (None, 32, 64, 64, 8 0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_145 (LeakyReLU)     (None, 32, 64, 64, 8 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# x1_moving_ (Conv3D)             (None, 32, 64, 64, 1 3472        leaky_re_lu_149[0][0]
# __________________________________________________________________________________________________
# x1_static_ (Conv3D)             (None, 32, 64, 64, 1 3472        leaky_re_lu_145[0][0]
# __________________________________________________________________________________________________
# x1_moving_1_1 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_moving_[0][0]
# __________________________________________________________________________________________________
# x1_static_1_1 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_static_[0][0]
# __________________________________________________________________________________________________
# x1_moving_1_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_moving_1_1[0][0]
# __________________________________________________________________________________________________
# x1_static_1_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_static_1_1[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 32, 64, 64, 1 0           x1_moving_1_2[0][0]
#                                                                  x1_moving_[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 32, 64, 64, 1 0           x1_static_1_2[0][0]
#                                                                  x1_static_[0][0]
# __________________________________________________________________________________________________
# x1_moving_2_1 (Conv3D)          (None, 32, 64, 64, 1 6928        add_78[0][0]
# __________________________________________________________________________________________________
# x1_static_2_1 (Conv3D)          (None, 32, 64, 64, 1 6928        add_72[0][0]
# __________________________________________________________________________________________________
# x1_moving_2_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_moving_2_1[0][0]
# __________________________________________________________________________________________________
# x1_static_2_2 (Conv3D)          (None, 32, 64, 64, 1 6928        x1_static_2_1[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 32, 64, 64, 1 0           x1_moving_2_2[0][0]
#                                                                  add_78[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 32, 64, 64, 1 0           x1_static_2_2[0][0]
#                                                                  add_72[0][0]
# __________________________________________________________________________________________________
# x2_moving (Conv3D)              (None, 16, 32, 32, 1 6928        add_79[0][0]
# __________________________________________________________________________________________________
# x2_static (Conv3D)              (None, 16, 32, 32, 1 6928        add_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 32, 32, 1 64          x2_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 32, 32, 1 64          x2_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_150 (LeakyReLU)     (None, 16, 32, 32, 1 0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_146 (LeakyReLU)     (None, 16, 32, 32, 1 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# x2_moving_ (Conv3D)             (None, 16, 32, 32, 3 13856       leaky_re_lu_150[0][0]
# __________________________________________________________________________________________________
# x2_static_ (Conv3D)             (None, 16, 32, 32, 3 13856       leaky_re_lu_146[0][0]
# __________________________________________________________________________________________________
# x2_moving_1_1 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_moving_[0][0]
# __________________________________________________________________________________________________
# x2_static_1_1 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_static_[0][0]
# __________________________________________________________________________________________________
# x2_moving_1_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_moving_1_1[0][0]
# __________________________________________________________________________________________________
# x2_static_1_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_static_1_1[0][0]
# __________________________________________________________________________________________________
# add_80 (Add)                    (None, 16, 32, 32, 3 0           x2_moving_1_2[0][0]
#                                                                  x2_moving_[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 16, 32, 32, 3 0           x2_static_1_2[0][0]
#                                                                  x2_static_[0][0]
# __________________________________________________________________________________________________
# x2_moving_2_1 (Conv3D)          (None, 16, 32, 32, 3 27680       add_80[0][0]
# __________________________________________________________________________________________________
# x2_static_2_1 (Conv3D)          (None, 16, 32, 32, 3 27680       add_74[0][0]
# __________________________________________________________________________________________________
# x2_moving_2_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_moving_2_1[0][0]
# __________________________________________________________________________________________________
# x2_static_2_2 (Conv3D)          (None, 16, 32, 32, 3 27680       x2_static_2_1[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 16, 32, 32, 3 0           x2_moving_2_2[0][0]
#                                                                  add_80[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 16, 32, 32, 3 0           x2_static_2_2[0][0]
#                                                                  add_74[0][0]
# __________________________________________________________________________________________________
# x3_moving (Conv3D)              (None, 8, 16, 16, 32 27680       add_81[0][0]
# __________________________________________________________________________________________________
# x3_static (Conv3D)              (None, 8, 16, 16, 32 27680       add_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 16, 16, 32 128         x3_moving[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 16, 16, 32 128         x3_static[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_151 (LeakyReLU)     (None, 8, 16, 16, 32 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_147 (LeakyReLU)     (None, 8, 16, 16, 32 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# x3_moving_ (Conv3D)             (None, 8, 16, 16, 32 27680       leaky_re_lu_151[0][0]
# __________________________________________________________________________________________________
# x3_static_ (Conv3D)             (None, 8, 16, 16, 32 27680       leaky_re_lu_147[0][0]
# __________________________________________________________________________________________________
# x3_moving_1_1 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_moving_[0][0]
# __________________________________________________________________________________________________
# x3_static_1_1 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_static_[0][0]
# __________________________________________________________________________________________________
# x3_moving_1_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_moving_1_1[0][0]
# __________________________________________________________________________________________________
# x3_static_1_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_static_1_1[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 8, 16, 16, 32 0           x3_moving_1_2[0][0]
#                                                                  x3_moving_[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 8, 16, 16, 32 0           x3_static_1_2[0][0]
#                                                                  x3_static_[0][0]
# __________________________________________________________________________________________________
# x3_moving_2_1 (Conv3D)          (None, 8, 16, 16, 32 27680       add_82[0][0]
# __________________________________________________________________________________________________
# x3_static_2_1 (Conv3D)          (None, 8, 16, 16, 32 27680       add_76[0][0]
# __________________________________________________________________________________________________
# x3_moving_2_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_moving_2_1[0][0]
# __________________________________________________________________________________________________
# x3_static_2_2 (Conv3D)          (None, 8, 16, 16, 32 27680       x3_static_2_1[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 8, 16, 16, 32 0           x3_moving_2_2[0][0]
#                                                                  add_82[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 8, 16, 16, 32 0           x3_static_2_2[0][0]
#                                                                  add_76[0][0]
# __________________________________________________________________________________________________
# x4_moving (Conv3D)              (None, 4, 8, 8, 32)  27680       add_83[0][0]
# __________________________________________________________________________________________________
# x4_static (Conv3D)              (None, 4, 8, 8, 32)  27680       add_77[0][0]
# __________________________________________________________________________________________________
# concat_bottleNeck (Concatenate) (None, 4, 8, 8, 64)  0           x4_static[0][0]
#                                                                  x4_moving[0][0]
# __________________________________________________________________________________________________
# pred4 (Conv3D)                  (None, 4, 8, 8, 3)   5187        concat_bottleNeck[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_24 (UpSampling3D) (None, 8, 16, 16, 3) 0           pred4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_90 (TensorFlo [(5,)]               0           up_sampling3d_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_391 ( [()]                 0           tf_op_layer_Shape_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_392 ( [()]                 0           tf_op_layer_Shape_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_393 ( [()]                 0           tf_op_layer_Shape_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_810 (TensorFlo [()]                 0           tf_op_layer_strided_slice_391[0][
# __________________________________________________________________________________________________
# tf_op_layer_Cast_815 (TensorFlo [()]                 0           tf_op_layer_strided_slice_392[0][
# __________________________________________________________________________________________________
# tf_op_layer_Cast_820 (TensorFlo [()]                 0           tf_op_layer_strided_slice_393[0][
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1081 (TensorFlo [()]                 0           tf_op_layer_Cast_810[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1083 (TensorFlo [()]                 0           tf_op_layer_Cast_815[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1085 (TensorFlo [()]                 0           tf_op_layer_Cast_820[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_391 (Tensor [()]                 0           tf_op_layer_Sub_1081[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GreaterEqual_90 (Te [()]                 0           tf_op_layer_Cast_810[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_393 (Tensor [()]                 0           tf_op_layer_Sub_1083[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GreaterEqual_91 (Te [()]                 0           tf_op_layer_Cast_815[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_395 (Tensor [()]                 0           tf_op_layer_Sub_1085[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GreaterEqual_92 (Te [()]                 0           tf_op_layer_Cast_820[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_270 (Tenso [()]                 0           tf_op_layer_GreaterEqual_90[0][0]
#                                                                  tf_op_layer_Maximum_391[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_273 (Tenso [()]                 0           tf_op_layer_GreaterEqual_91[0][0]
#                                                                  tf_op_layer_Maximum_393[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_276 (Tenso [()]                 0           tf_op_layer_GreaterEqual_92[0][0]
#                                                                  tf_op_layer_Maximum_395[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_813 (TensorFlo [()]                 0           tf_op_layer_SelectV2_270[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1080 (TensorFlo [()]                 0           tf_op_layer_Cast_810[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_818 (TensorFlo [()]                 0           tf_op_layer_SelectV2_273[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1082 (TensorFlo [()]                 0           tf_op_layer_Cast_815[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_823 (TensorFlo [()]                 0           tf_op_layer_SelectV2_276[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1084 (TensorFlo [()]                 0           tf_op_layer_Cast_820[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_120 (TensorFl [(None,)]            0           tf_op_layer_Cast_813[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_390 (Tensor [()]                 0           tf_op_layer_Sub_1080[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_121 (TensorFl [(None,)]            0           tf_op_layer_Cast_818[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_392 (Tensor [()]                 0           tf_op_layer_Sub_1082[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_122 (TensorFl [(None,)]            0           tf_op_layer_Cast_823[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_394 (Tensor [()]                 0           tf_op_layer_Sub_1084[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_812 (TensorFlo [()]                 0           tf_op_layer_Maximum_391[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_814 (TensorFlo [(None,)]            0           tf_op_layer_Range_120[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_271 (Tenso [(1,)]               0           tf_op_layer_Maximum_390[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_817 (TensorFlo [()]                 0           tf_op_layer_Maximum_393[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_819 (TensorFlo [(None,)]            0           tf_op_layer_Range_121[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_274 (Tenso [(1,)]               0           tf_op_layer_Maximum_392[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_822 (TensorFlo [()]                 0           tf_op_layer_Maximum_395[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_824 (TensorFlo [(None,)]            0           tf_op_layer_Range_122[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_277 (Tenso [(1,)]               0           tf_op_layer_Maximum_394[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_90 (TensorF [(1,)]               0           tf_op_layer_Cast_812[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_210 (Tensor [(None,)]            0           tf_op_layer_Cast_814[0][0]
#                                                                  tf_op_layer_SelectV2_271[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_91 (TensorF [(1,)]               0           tf_op_layer_Cast_817[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_211 (Tensor [(None,)]            0           tf_op_layer_Cast_819[0][0]
#                                                                  tf_op_layer_SelectV2_274[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_92 (TensorF [(1,)]               0           tf_op_layer_Cast_822[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_212 (Tensor [(None,)]            0           tf_op_layer_Cast_824[0][0]
#                                                                  tf_op_layer_SelectV2_277[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1110 (TensorFlo [(None,)]            0           tf_op_layer_RealDiv_90[0][0]
#                                                                  tf_op_layer_Reshape_210[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1111 (TensorFlo [(None,)]            0           tf_op_layer_RealDiv_91[0][0]
#                                                                  tf_op_layer_Reshape_211[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1112 (TensorFlo [(None,)]            0           tf_op_layer_RealDiv_92[0][0]
#                                                                  tf_op_layer_Reshape_212[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_300 (TensorFl [(None,)]            0           tf_op_layer_Mul_1110[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_301 (TensorFl [(None,)]            0           tf_op_layer_Mul_1111[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_302 (TensorFl [(None,)]            0           tf_op_layer_Mul_1112[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_90 (TensorFl [(None,)]            0           tf_op_layer_AddV2_300[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_272 (Tenso [(1,)]               0           tf_op_layer_Cast_810[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_91 (TensorFl [(None,)]            0           tf_op_layer_AddV2_301[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_275 (Tenso [(1,)]               0           tf_op_layer_Cast_815[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_92 (TensorFl [(None,)]            0           tf_op_layer_AddV2_302[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SelectV2_278 (Tenso [(1,)]               0           tf_op_layer_Cast_820[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_90 (TensorFlo [(None,)]            0           tf_op_layer_concat_90[0][0]
#                                                                  tf_op_layer_SelectV2_272[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_91 (TensorFlo [(None,)]            0           tf_op_layer_concat_91[0][0]
#                                                                  tf_op_layer_SelectV2_275[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Slice_92 (TensorFlo [(None,)]            0           tf_op_layer_concat_92[0][0]
#                                                                  tf_op_layer_SelectV2_278[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_90 (TensorFlow [()]                 0           tf_op_layer_Slice_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_91 (TensorFlow [()]                 0           tf_op_layer_Slice_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Size_92 (TensorFlow [()]                 0           tf_op_layer_Slice_92[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_packed_30 (TensorFl [(3,)]               0           tf_op_layer_Size_90[0][0]
#                                                                  tf_op_layer_Size_91[0][0]
#                                                                  tf_op_layer_Size_92[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_213 (Tensor [(None, 1, 1)]       0           tf_op_layer_Slice_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Fill_60 (TensorFlow [(None, None, None)] 0           tf_op_layer_packed_30[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_214 (Tensor [(1, None, 1)]       0           tf_op_layer_Slice_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_215 (Tensor [(1, 1, None)]       0           tf_op_layer_Slice_92[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_56 (Conv3DTran (None, 8, 16, 16, 32 27680       x4_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1113 (TensorFlo [(None, None, None)] 0           tf_op_layer_Reshape_213[0][0]
#                                                                  tf_op_layer_Fill_60[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1114 (TensorFlo [(None, None, None)] 0           tf_op_layer_Reshape_214[0][0]
#                                                                  tf_op_layer_Fill_60[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1115 (TensorFlo [(None, None, None)] 0           tf_op_layer_Reshape_215[0][0]
#                                                                  tf_op_layer_Fill_60[0][0]
# __________________________________________________________________________________________________
# up3_moving (Conv3D)             (None, 8, 16, 16, 32 1056        conv3d_transpose_56[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_270 (TensorFl [(None, None, None,  0           tf_op_layer_Mul_1113[0][0]
#                                                                  tf_op_layer_Mul_1114[0][0]
#                                                                  tf_op_layer_Mul_1115[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_390 ( [()]                 0           tf_op_layer_Shape_90[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_152 (LeakyReLU)     (None, 8, 16, 16, 32 0           up3_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_270 (Ten [(1, None, None, Non 0           tf_op_layer_stack_270[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Pack_30 (TensorFlow [(5,)]               0           tf_op_layer_strided_slice_390[0][
# __________________________________________________________________________________________________
# concat3_moving (Concatenate)    (None, 8, 16, 16, 64 0           add_83[0][0]
#                                                                  leaky_re_lu_152[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Tile_30 (TensorFlow [(None, None, None,  0           tf_op_layer_ExpandDims_270[0][0]
#                                                                  tf_op_layer_Pack_30[0][0]
# __________________________________________________________________________________________________
# dex3_moving (Conv3D)            (None, 8, 16, 16, 32 55328       concat3_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_303 (TensorFl [(None, 8, 16, 16, 3 0           tf_op_layer_Tile_30[0][0]
#                                                                  up_sampling3d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_154 (LeakyReLU)     (None, 8, 16, 16, 32 0           dex3_moving[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_210 (Tensor [(None, 8, 16, 16, 3 0           tf_op_layer_AddV2_303[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_396 (Tensor [(None, 8, 16, 16, 3 0           tf_op_layer_Minimum_210[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_91 (TensorFlo [(5,)]               0           leaky_re_lu_154[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_400 ( [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_396[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_396 ( [()]                 0           tf_op_layer_Shape_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_401 ( [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_396[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_397 ( [()]                 0           tf_op_layer_Shape_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_304 (TensorFl [(None, 8, 16, 16)]  0           tf_op_layer_strided_slice_400[0][
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1086 (TensorFlo [()]                 0           tf_op_layer_strided_slice_396[0][
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_305 (TensorFl [(None, 8, 16, 16)]  0           tf_op_layer_strided_slice_401[0][
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1087 (TensorFlo [()]                 0           tf_op_layer_strided_slice_397[0][
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_402 ( [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_396[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_398 ( [()]                 0           tf_op_layer_Shape_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1116 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_304[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_825 (TensorFlo [()]                 0           tf_op_layer_Sub_1086[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1118 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_305[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_826 (TensorFlo [()]                 0           tf_op_layer_Sub_1087[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_306 (TensorFl [(None, 8, 16, 16)]  0           tf_op_layer_strided_slice_402[0][
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1088 (TensorFlo [()]                 0           tf_op_layer_strided_slice_398[0][
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1117 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_1116[0][0]
#                                                                  tf_op_layer_Cast_825[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1119 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_1118[0][0]
#                                                                  tf_op_layer_Cast_826[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1120 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_306[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_827 (TensorFlo [()]                 0           tf_op_layer_Sub_1088[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Floor_90 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_1117[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Floor_91 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_1119[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1121 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_1120[0][0]
#                                                                  tf_op_layer_Cast_827[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_828 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Floor_90[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_829 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Floor_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Floor_92 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_1121[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1089 (TensorFlo [()]                 0           tf_op_layer_strided_slice_396[0][
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_308 (TensorFl [(None, 8, 16, 16)]  0           tf_op_layer_Cast_829[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1090 (TensorFlo [()]                 0           tf_op_layer_strided_slice_397[0][
# __________________________________________________________________________________________________
# tf_op_layer_Cast_830 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Floor_92[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_307 (TensorFl [(None, 8, 16, 16)]  0           tf_op_layer_Cast_828[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_211 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Cast_828[0][0]
#                                                                  tf_op_layer_Sub_1089[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_214 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_308[0][0]
#                                                                  tf_op_layer_Sub_1090[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_309 (TensorFl [(None, 8, 16, 16)]  0           tf_op_layer_Cast_830[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1091 (TensorFlo [()]                 0           tf_op_layer_strided_slice_398[0][
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_212 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_307[0][0]
#                                                                  tf_op_layer_Sub_1089[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_213 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Cast_829[0][0]
#                                                                  tf_op_layer_Sub_1090[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_397 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_211[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_400 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_214[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_216 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_AddV2_309[0][0]
#                                                                  tf_op_layer_Sub_1091[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_395 ( [()]                 0           tf_op_layer_Shape_91[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_398 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_212[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_399 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_213[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum_215 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Cast_830[0][0]
#                                                                  tf_op_layer_Sub_1091[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_831 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_397[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_834 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_400[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_402 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_216[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_92 (TensorFlo [(4,)]               0           tf_op_layer_Maximum_397[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Range_123 (TensorFl [(None,)]            0           tf_op_layer_strided_slice_395[0][
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_216/shape ( [(4,)]               0           tf_op_layer_strided_slice_395[0][
# __________________________________________________________________________________________________
# tf_op_layer_Maximum_401 (Tensor [(None, 8, 16, 16)]  0           tf_op_layer_Minimum_215[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_833 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_399[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_832 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_398[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_57 (Conv3DTran (None, 8, 16, 16, 32 27680       x4_static[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1092 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Mul_1117[0][0]
#                                                                  tf_op_layer_Cast_831[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1093 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Cast_834[0][0]
#                                                                  tf_op_layer_Mul_1119[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Cast_836 (TensorFlo [(None, 8, 16, 16)]  0           tf_op_layer_Maximum_402[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Fill_61 (TensorFlow [(None, 8, 16, 16)]  0           tf_op_layer_Shape_92[0][0]
# ...
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1281 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Sub_1251[0][0]
#                                                                  tf_op_layer_Sub_1252[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1253 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Cast_944[0][0]
#                                                                  tf_op_layer_Mul_1269[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1283 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Sub_1254[0][0]
#                                                                  tf_op_layer_Sub_1255[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1256 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1269[0][0]
#                                                                  tf_op_layer_Cast_943[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1285 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Sub_1257[0][0]
#                                                                  tf_op_layer_Sub_1258[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1259 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1269[0][0]
#                                                                  tf_op_layer_Cast_943[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1272 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1271[0][0]
#                                                                  tf_op_layer_Sub_1238[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_307 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_450[0][0]
#                                                                  tf_op_layer_Maximum_451[0][0]
#                                                                  tf_op_layer_Maximum_453[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1274 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1273[0][0]
#                                                                  tf_op_layer_Sub_1241[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_308 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_450[0][0]
#                                                                  tf_op_layer_Maximum_452[0][0]
#                                                                  tf_op_layer_Maximum_453[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1276 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1275[0][0]
#                                                                  tf_op_layer_Sub_1244[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_309 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_450[0][0]
#                                                                  tf_op_layer_Maximum_451[0][0]
#                                                                  tf_op_layer_Maximum_454[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1278 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1277[0][0]
#                                                                  tf_op_layer_Sub_1247[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_310 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_450[0][0]
#                                                                  tf_op_layer_Maximum_452[0][0]
#                                                                  tf_op_layer_Maximum_454[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1280 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1279[0][0]
#                                                                  tf_op_layer_Sub_1250[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_311 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_449[0][0]
#                                                                  tf_op_layer_Maximum_451[0][0]
#                                                                  tf_op_layer_Maximum_453[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1282 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1281[0][0]
#                                                                  tf_op_layer_Sub_1253[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_312 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_449[0][0]
#                                                                  tf_op_layer_Maximum_452[0][0]
#                                                                  tf_op_layer_Maximum_453[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1284 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1283[0][0]
#                                                                  tf_op_layer_Sub_1256[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_313 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_449[0][0]
#                                                                  tf_op_layer_Maximum_451[0][0]
#                                                                  tf_op_layer_Maximum_454[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1286 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_Mul_1285[0][0]
#                                                                  tf_op_layer_Sub_1259[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_stack_314 (TensorFl [(None, 64, 128, 128 0           tf_op_layer_Mul_1270[0][0]
#                                                                  tf_op_layer_Maximum_449[0][0]
#                                                                  tf_op_layer_Maximum_452[0][0]
#                                                                  tf_op_layer_Maximum_454[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_307 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1272[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_272 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_307[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_308 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1274[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_273 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_308[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_309 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1276[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_274 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_309[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_310 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1278[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_275 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_310[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_311 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1280[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_276 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_311[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_312 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1282[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_277 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_312[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_313 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1284[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_278 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_313[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_314 (Ten [(None, 64, 128, 128 0           tf_op_layer_Mul_1286[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_GatherNd_279 (Tenso [(None, 64, 128, 128 0           moving[0][0]
#                                                                  tf_op_layer_stack_314[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1287 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_307[0][0]
#                                                                  tf_op_layer_GatherNd_272[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1288 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_308[0][0]
#                                                                  tf_op_layer_GatherNd_273[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1289 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_309[0][0]
#                                                                  tf_op_layer_GatherNd_274[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1290 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_310[0][0]
#                                                                  tf_op_layer_GatherNd_275[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1291 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_311[0][0]
#                                                                  tf_op_layer_GatherNd_276[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1292 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_312[0][0]
#                                                                  tf_op_layer_GatherNd_277[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1293 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_313[0][0]
#                                                                  tf_op_layer_GatherNd_278[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1294 (TensorFlo [(None, 64, 128, 128 0           tf_op_layer_ExpandDims_314[0][0]
#                                                                  tf_op_layer_GatherNd_279[0][0]
# __________________________________________________________________________________________________
# deep_x2_concat (Concatenate)    (None, 8, 16, 16, 64 0           leaky_re_lu_154[0][0]
#                                                                  leaky_re_lu_155[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_moved_6 (TensorFlow [(None, 64, 128, 128 0           tf_op_layer_Mul_1287[0][0]
#                                                                  tf_op_layer_Mul_1288[0][0]
#                                                                  tf_op_layer_Mul_1289[0][0]
#                                                                  tf_op_layer_Mul_1290[0][0]
#                                                                  tf_op_layer_Mul_1291[0][0]
#                                                                  tf_op_layer_Mul_1292[0][0]
#                                                                  tf_op_layer_Mul_1293[0][0]
#                                                                  tf_op_layer_Mul_1294[0][0]
# ==================================================================================================
# Total params: 1,304,127
# Trainable params: 1,193,215
# Non-trainable params: 110,912
# __________________________________________________________________________________________________

# %%
output = model.predict(sample_loader)
moved = output['moved']
deformation = output['deformation']
print(deformation.shape)

filename = "./BTCV_Data/gt_resize/1.nii.gz"
gt_moving = nib.load(filename).get_fdata()
gt_moving = gt_moving.swapaxes(0,2)
gt_moving = tf.expand_dims(gt_moving, axis=0)
gt_moving = tf.expand_dims(gt_moving, axis=4)
print(gt_moving.shape)

nb, nd, nh, nw, nc = tf.shape(deformation)

# Regular grid.
grid = regular_grid_3d(nd, nh, nw)

grid = tf.expand_dims(grid, axis=0) 
multiples = tf.stack([nb, 1, 1, 1, 1])
grid = tf.tile(grid, multiples)

print(deformation.shape)
grid_new = grid + deformation
grid_new = tf.clip_by_value(grid_new, -1, 1)

gt_moving = tf.cast(gt_moving, tf.float32)

gt = grid_sample_3d(gt_moving, grid_new, name='gt')
# print(gt.shape)
gt = gt.numpy()
gt = gt.squeeze()
print(gt.shape)
gt = gt.swapaxes(0,2)
print(gt.shape)
x = nib.Nifti1Image(gt, None) 
nib.save(x,'./BTCV_Data/gt_moved결과_0809_3.nii.gz')
# Out:
# (1, 64, 128, 128, 3)
# (1, 64, 128, 128, 1)
# (1, 64, 128, 128, 3)
# (64, 128, 128)
# (128, 128, 64)

# %%
def dice_coef(y_true, y_pred_bin):
                    
    intersection = 2.0 * np.sum(y_true * y_pred_bin)
    union = (np.sum(y_true) + np.sum(y_pred_bin))
    return (intersection / union)

# %%
filename = "./chaos_train_voxel/gtaffine.nii.gz"

rgt = nib.load(filename).get_fdata()
rgt = rgt.swapaxes(0,2)

mov = np.squeeze(moved[0])

print(dice_coef(mov, rgt))
# Out:
# 0.2385860440177458

# %%
-gt_moved = gt_moved.swapaxes(0,2)

c = nib.Nifti1Image(gt_moved, None)
nib.save(c,'0530 결과/gt0530_04.nii.gz')

# %%
output = model.predict(sample_loader)
moved = output['moved']
moved = moved * (max_value - min_value) + min_value

a = 1
j = 0
for i in range (0, 39):
    filename = "./BTCV_Data/gt_resize/" + str(a) + ".nii.gz"
model.load_weights(checkpoint_path)
    if os.path.isfile(filename):
        
        x = moved[j]
        x = np.squeeze(x)
        x = x.swapaxes(0,2) 
        print(a, ":", x.shape )
        savename = "./BTCV_Data/6.최종결과_resize10/" + str(a) + ".nii.gz"
        x = nib.Nifti1Image(x, None) 
        nib.save(x,savename)
        
        j += 1
        
    a += 1
# Out:
# 1 : (128, 128, 64, 3)
# 2 : (128, 128, 64, 3)
# 3 : (128, 128, 64, 3)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-2c664886e821> in <module>
#      10     if os.path.isfile(filename):
#      11
# ---> 12         x = moved[j]
#      13         x = np.squeeze(x)
#      14         x = x.swapaxes(0,2)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
def dice_coef_multilabel(y_true, y_pred, labels=11):
#     y_true = tf.convert_to_tensor(y_true)
#     y_pred = tf.convert_to_tensor(y_pred)
    
    #w,h,d = y_true.shape
    result = 0
    union = (np.sum(y_pred) + np.sum(y_true))
    #print("union:" + str(union))
    intersection = 0
    for m in range(1,labels+1):
        intersection += np.sum(y_pred[y_true==m])*2.0 
    
#         print("label: "+ str(m) +" intersection: "+str(np.sum(y_pred[y_true==m])*2.0 ))
        dice = intersection / union
        print("label: "+ str(m) + "result: "+ str(round((dice),2)))        
    print("total Dice:"+str(round(dice,2)))
    return round(dice,2)

def dice_coef(y_true, y_pred):
    y_true_f = y_true.flatten()
    y_pred_f = y_pred.flatten()
    intersection = np.sum(y_true_f * y_pred_f)
    smooth = 0.0001
    return (2. * intersection + smooth) / (np.sum(y_true_f) + np.sum(y_pred_f) + smooth)

def dice_coef_multilabel(y_true, y_pred, numLabels):
    dice=0
    for index in range(numLabels):
        dice += dice_coef(y_true[:,:,:,index], y_pred[:,:,:,index])
    return dice/numLabels

# %%
aaa = 1
for i in range (0, 1):
    #filename1 = "./BTCV_Data/gt_resize/" + str(aaa) + ".nii.gz"
    filename1 = "./BTCV_Data/gt_resize/40.nii.gz"
#     filename2 = "./BTCV_Data/gt_change_vox_r10/" + str(aaa) + ".nii.gz"
    filename2 = "./BTCV_Data/gt_resize/40.nii.gz"
    if os.path.isfile(filename2):
        print("Number: " + str(aaa))
        x1 = nib.load(filename1).get_fdata()
        x1 = x1.astype(np.float32)
        x2 = nib.load(filename2).get_fdata()
        x2 = x2.astype(np.float32)
        # print(x1.shape)
        dice_coef_multilabel(x1,x2,11)
#         print("Result Dice: "+ str(dice_coef_multilabel(x1,x2,12)))
    
    aaa += 1
# Out:
# Number: 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-fb01db9c80f2> in <module>
#      12         x2 = x2.astype(np.float32)
#      13         # print(x1.shape)
# ---> 14         dice_coef_multilabel(x1,x2,11)
#      15 #         print("Result Dice: "+ str(dice_coef_multilabel(x1,x2,12)))
#      16
#
# <ipython-input-59-2b358f2e2599> in dice_coef_multilabel(y_true, y_pred, numLabels)
#      27     dice=0
#      28     for index in range(numLabels):
# ---> 29         dice += dice_coef(y_true[:,:,:,index], y_pred[:,:,:,index])
#      30     return dice/numLabels
#
# IndexError: too many indices for array

# %%
filename1 = "./BTCV_Data/gt_resize/40.nii.gz"
filename2 = "./BTCV_Data/gt_moved결과_0805_2.nii.gz"
x1 = nib.load(filename1).get_fdata()
x1 = x1.astype(np.float32)
x2 = nib.load(filename2).get_fdata()
x2 = x2.astype(np.float32)    

def dice_coef_multilabel(y_true, y_pred, labels=11):n
    w, h, d = y_true.shape
    label_interaction = []
    label_union = []
    total_dice = 0
    # print(y_true.shape)
    for m in range(0, labels+1):
        interact = 0
        gakgak = 0 
        for i in range(0, w):
            for j in range(0, h):
                for k in range(0, d):
                        if y_true[i][j][k] == m and y_pred[i][j][k] == m:
                            interact += 1
                        if y_true[i][j][k] == m:
                            gakgak += 1
                        if y_pred[i][j][k] == m:
                            gakgak += 1
        if interact != None:
            label_interaction.append(interact)
        else:
            label_interaction.append(0)
        if gakgak != None:
            label_union.append(gakgak)
        else:
            label_union.append(0)
        
        #print(label_interaction)
        
        dice = (label_interaction[m]*2) / label_union[m]
        total_dice += dice
        print("class: "+ str(m) + "    Dice: "+ str(dice))
        
    print("total_dice: " + str(total_dice / (labels+1)))

        
dice_coef_multilabel(x1, x2)
# Out:
# class: 0    Dice: 0.9683487545079204
# class: 1    Dice: 0.0
# class: 2    Dice: 0.0
# class: 3    Dice: 0.0
# class: 4    Dice: 0.0
# class: 5    Dice: 0.0
# class: 6    Dice: 0.0
# class: 7    Dice: 0.0
# class: 8    Dice: 0.0
# class: 9    Dice: 0.0
# class: 10    Dice: 0.0
# class: 11    Dice: 0.0
# total_dice: 0.08069572954232669
