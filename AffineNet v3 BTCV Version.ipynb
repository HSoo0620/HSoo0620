# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.layers as layers
import matplotlib.pyplot as plt
import math
from tensorflow.keras.models import Model
from tensorflow.keras.layers import BatchNormalization, Add, UpSampling3D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv3D, Input, MaxPooling3D, Dropout, concatenate, UpSampling3D, ReLU
from tensorflow.keras import backend as K
import nibabel as nib
import os 


def global_normalized_cross_correlation_loss():
    def ncc(y_true, y_pred):
        """Computes the normalized cross-correlation (NCC) loss.

        Parameters
        ----------
        y_true : tf.Tensor
            The static image to which the moving image is aligned.
        y_pred : tf.Tensor
            The moving image, the same shape as the static image.

        Returns
        -------
        loss : tf.Tensor, shape ()
            Normalized cross-correlation loss between the static and the
            moving images, averaged over the batch. Range is [-1.0, 1.0].
            The best value is -1 (perfect match) and the worst is 1.

        References
        ----------
        .. [1] `Wikipedia entry for the Cross-correlation
               <https://en.wikipedia.org/wiki/Cross-correlation>`_

        """
        ndim = tf.keras.backend.ndim(y_true)-2

        # shape (N, 1, 1, C)
        y_true_mean = tf.reduce_mean(y_true, axis=range(1, ndim+1),
                                     keepdims=True)
        y_pred_mean = tf.reduce_mean(y_pred, axis=range(1, ndim+1),
                                     keepdims=True)
        plt.ylabel('Loss')

        y_true_hat = tf.math.l2_normalize(y_true-y_true_mean,
                                          axis=range(1, ndim+1))

        y_pred_hat = tf.math.l2_normalize(y_pred-y_pred_mean,
                                          axis=range(1, ndim+1))

        return -tf.reduce_mean(tf.reduce_sum(y_true_hat * y_pred_hat,
                                             axis=range(1, ndim+1)))
    return ncc


def local_normalized_cross_correlation_loss(window=(9,9,9), eps=1e-5):
    """
    Code borrowed from https://github.com/voxelmorph/voxelmorph/blob/legacy/src/losses.py#L28
    Paper: https://openaccess.thecvf.com/content_cvpr_2018/papers/Balakrishnan_An_Unsupervised_Learning_CVPR_2018_paper.pdf
    """
    def ncc(I, J, window=window):
        # get dimension of volume
        # assumes I, J are sized [batch_size, *vol_shape, nb_feats]
        # ndims = len(I.get_shape().as_list()) - 2
        ndims = tf.keras.backend.ndim(I)-2
        assert ndims in [1, 2, 3], "volumes should be 1 to 3 dimensions. found: %d" % ndims

        # set window size
        if window is None:
            window = [9] * ndims

        # get convolution function
        conv_fn = getattr(tf.nn, 'conv%dd' % ndims)

        # compute CC squares
        I2 = I*I
        J2 = J*J
        IJ = I*J

        # compute filters
        sum_filt = tf.ones([*window, 1, 1])
        strides = [1] * (ndims + 2)
        padding = 'SAME'

        # compute local sums via convolution
        I_sum = conv_fn(I, sum_filt, strides, padding)
        J_sum = conv_fn(J, sum_filt, strides, padding)
        I2_sum = conv_fn(I2, sum_filt, strides, padding)
        J2_sum = conv_fn(J2, sum_filt, strides, padding)
        IJ_sum = conv_fn(IJ, sum_filt, strides, padding)

        # compute cross correlation
        win_size = np.prod(window)
        u_I = I_sum/win_size
        u_J = J_sum/win_size

        cross = IJ_sum - u_J*I_sum - u_I*J_sum + u_I*u_J*win_size
        I_var = I2_sum - 2 * u_I * I_sum + u_I*u_I*win_size
        J_var = J2_sum - 2 * u_J * J_sum + u_J*u_J*win_size

        cc = cross*cross / (I_var*J_var + eps)

        # return negative cc.
        return -tf.reduce_mean(cc)
    return ncc

# vein. Portal veins are well enhanced and some enhancement of the hepatic veins is also seen on the portal venous phase. T
def gradient_loss(norm=2):
    """
    Code borrowed from https://github.com/voxelmorph/voxelmorph/blob/legacy/pytorch/losses.py#L13
    Paper: https://openaccess.thecvf.com/content_cvpr_2018/papers/Balakrishnan_An_Unsupervised_Learning_CVPR_2018_paper.pdf
    """
    def grad_loss(_, phi):
        di = tf.abs(phi[:, 1:, :, :, :] - phi[:, :-1, :, :, :])
        dj = tf.abs(phi[:, :, 1:, :, :] - phi[:, :, :-1, :, :])
        dk = tf.abs(phi[:, :, :, 1:, :] - phi[:, :, :, :-1, :])

        loss = tf.reduce_mean(di) + tf.reduce_mean(dj) + tf.reduce_mean(dk)
        if norm == 2:
            loss = tf.reduce_mean(di**2) + tf.reduce_mean(dj**2) + tf.reduce_mean(dk**2)    
        return loss
    return grad_loss

def regular_grid_3d(depth, height, width):
    """Returns a 3-D regular grid.

    Parameters
    ----------
    depth : int
        The desired depth of the grid.
    height : int
        The desired height of the grid.
    width : int
        The desired width of the grid.
    Returns
    -------
    grid : tf.Tensor, shape (D, H, W, 3)
        A 3-D regular grid, values normalized to [-1.0, 1.0]
        range.

    Notes
    -----
    Sampling using the regular grid is an identity transformation, i.e.,
    it results in the same input and output images.

    References
    ----------
    .. [1] `NumPy, "numpy.meshgrid"
        <https://numpy.org/doc/stable/reference/generated/numpy.meshgrid.html>`_
    .. [2] `NumPy, "numpy.indices"
        <https://numpy.org/doc/stable/reference/generated/numpy.indices.html>`_

    """
    i = tf.linspace(-1.0, 1.0, depth)
    j = tf.linspace(-1.0, 1.0, height)
    k = tf.linspace(-1.0, 1.0, width)

    I, J, K = tf.meshgrid(i, j, k, indexing='ij')

    grid = tf.stack([I, J, K], axis=-1)
    return grid


def grid_sample_3d(moving, grid, name=None):
    """Given a moving image and a sampling grid as input, computes the
    transformed image by sampling the moving image at locations given by
    the grid.

    Parameters
    ----------
    moving : tf.Tensor, shape (N, D, H, W, C)
        The moving image.
    grid : tf.Tensor, shape (N, D, H, W, C)
        A tensor of sampling points (x, y, z). The x, y and z values should be
        normalized to [-1.0, 1.0] range.
    name : str
        Name for the operation.

    Returns
    -------
    moved : tf.Tensor, shape (N, D, H, W, C)
        The transformed image.

    Notes
    -----
    Let M be the moving image of shape (H, W, C), T be the transformed
    image of the same shape and G be the 2D sampling grid of shape
    (H, W, 2). The value of T at a location (x, y) is T[y, x, :] =
    M[y', x', :] where [x', y'] = G[y, x, :].

    Further, [x', y'] = [x + dx, y + dy] where [dx, dy] are the
    displacements outputted by the CNN. When dx and dy are 0, the
    sampling grid G is a regular grid and the transformed image is the
    same as the moving image.

    Since the sampling point (x + dx, y + dy) can be non-integral, the
    value M[y', x'] is calculated using bi-linear interpolation.

    References
    ----------
    .. [1] `Jaderberg, Max, Karen Simonyan, and Andrew Zisserman. "Spatial
        transformer networks." Advances in neural information processing
        systems. 2015. <https://arxiv.org/abs/1506.02025>`_
    .. [2] `TensorFlow implementation of spatial transformer networks.
        <https://github.com/tensorflow/models/tree/master/research/transformer>`_
    .. [3] `Spatial Transformer Networks by Kushagra Bhatnagar
        <https://link.medium.com/0b2OrmqVO5>`_
        
    """
    nb, nd, nh, nw, nc = tf.shape(moving)
    
    i = grid[..., 0]  # shape (N, D, H, W)
    j = grid[..., 1]
    k = grid[..., 2]
    i = tf.cast(i, 'float32')
    j = tf.cast(j, 'float32')
    k = tf.cast(k, 'float32')

    # Scale i, j and k from [-1.0, 1.0] to [0, D], [0, H] and [0, W] respectively.
    i = (i + 1.0) * 0.5 * tf.cast(nd-1, 'float32')
    j = (j + 1.0) * 0.5 * tf.cast(nh-1, 'float32')
    k = (k + 1.0) * 0.5 * tf.cast(nw-1, 'float32')

    i_max = tf.cast(nd - 1, 'int32')
    j_max = tf.cast(nh - 1, 'int32')
    k_max = tf.cast(nw - 1, 'int32')
    zero = tf.constant(0, 'int32')

    # The value at (i, j, k) is a weighted average of the values at the
    # eight nearest integer locations: (i0, j0, k0), (i0, j0, k1), (i0, j1, k0),
    # (i0, j1, k1), (i1, j0, k0), (i1, j0, k1), (i1, j1, k0) and (i1, j1, k1)
    # where i0 = floor(i), i1 = ceil(i).
    i0 = tf.cast(tf.floor(i), 'int32')
    i1 = i0 + 1
    j0 = tf.cast(tf.floor(j), 'int32')
    j1 = j0 + 1
    k0 = tf.cast(tf.floor(k), 'int32')
    k1 = k0 + 1

    # Make sure indices are within the boundaries of the image.
    i0 = tf.clip_by_value(i0, zero, i_max)
    i1 = tf.clip_by_value(i1, zero, i_max)
    j0 = tf.clip_by_value(j0, zero, j_max)
    j1 = tf.clip_by_value(j1, zero, j_max)
    k0 = tf.clip_by_value(k0, zero, k_max)
    k1 = tf.clip_by_value(k1, zero, k_max)

    # Collect indices of the four corners.
    b = tf.ones_like(i0) * tf.reshape(tf.range(nb), [nb, 1, 1, 1])
    idx_a = tf.stack([b, i1, j0, k0], axis=-1)  # all front-top-left corners
    idx_b = tf.stack([b, i1, j1, k0], axis=-1)  # all front-bottom-left corners
    idx_c = tf.stack([b, i1, j0, k1], axis=-1)  # all front-top-right corners
    idx_d = tf.stack([b, i1, j1, k1], axis=-1)  # all front-bottom-right corners
    idx_e = tf.stack([b, i0, j0, k0], axis=-1)  # all back-top-left corners
    idx_f = tf.stack([b, i0, j1, k0], axis=-1)  # all back-bottom-left corners
    idx_g = tf.stack([b, i0, j0, k1], axis=-1)  # all back-top-right corners
    idx_h = tf.stack([b, i0, j1, k1], axis=-1)  # all back-bottom-right corners
    # shape (N, D, H, W, 3)

    # Collect values at the corners.
    moving_a = tf.gather_nd(moving, idx_a)  # all front-top-left values
    moving_b = tf.gather_nd(moving, idx_b)  # all front-bottom-left values
    moving_c = tf.gather_nd(moving, idx_c)  # all front-top-right values
    moving_d = tf.gather_nd(moving, idx_d)  # all front-bottom-right values
    moving_e = tf.gather_nd(moving, idx_e)  # all back-top-left values
    moving_f = tf.gather_nd(moving, idx_f)  # all back-bottom-left values
    moving_g = tf.gather_nd(moving, idx_g)  # all back-top-right values
    moving_h = tf.gather_nd(moving, idx_h)  # all back-bottom-right values
    # shape (N, D, H, W, C)

    i0_f = tf.cast(i0, 'float32')
    i1_f = tf.cast(i1, 'float32')
    j0_f = tf.cast(j0, 'float32')
    j1_f = tf.cast(j1, 'float32')
    k0_f = tf.cast(k0, 'float32')
    k1_f = tf.cast(k1, 'float32')

    # Calculate the weights.
    wa = tf.expand_dims((i - i0_f) * (j1_f - j) * (k1_f - k), axis=-1)
    wb = tf.expand_dims((i - i0_f) * (j - j0_f) * (k1_f - k), axis=-1)
    wc = tf.expand_dims((i - i0_f) * (j1_f - j) * (k - k0_f), axis=-1)
    wd = tf.expand_dims((i - i0_f) * (j - j0_f) * (k - k0_f), axis=-1)
    we = tf.expand_dims((i1_f - i) * (j1_f - j) * (k1_f - k), axis=-1)
    wf = tf.expand_dims((i1_f - i) * (j - j0_f) * (k1_f - k), axis=-1)
    wg = tf.expand_dims((i1_f - i) * (j1_f - j) * (k - k0_f), axis=-1)
    wh = tf.expand_dims((i1_f - i) * (j - j0_f) * (k - k0_f), axis=-1)

    # Calculate the weighted sum.
    moved = tf.add_n([wa * moving_a, wb * moving_b, wc * moving_c,
                      wd * moving_d, we * moving_e, wf * moving_f,
                      wg * moving_g, wh * moving_h], name=name)
    return moved

# %%
class AffineNet(object):
    def __init__(self, input_shape=(128, 128, 64), optimizer='adam', loss=None,
                 metrics=None, loss_weights=None):
        in_channels = 1
        out_channels = 3
        d, h, w = input_shape
        input_shape = input_shape + (in_channels,)
        moving = layers.Input(shape=input_shape, name='moving')
        static = layers.Input(shape=input_shape, name='static')
        moving_gt = layers.Input(shape=input_shape, name='moving_gt')
        
        x_in = layers.concatenate([static, moving], axis=-1)

        # encoder
        x1 = layers.Conv3D(16, kernel_size=3, strides=2, padding='same',
                            kernel_initializer='he_normal')(x_in)
        x1 = layers.LeakyReLU(alpha=0.2)(x1)  # 16
        x1 = layers.BatchNormalization()(x1)      

        x2 = layers.Conv3D(32, kernel_size=3, strides=2, padding='same',
                            kernel_initializer='he_normal')(x1)
        x2 = layers.LeakyReLU(alpha=0.2)(x2)  # 8
        x2 = layers.BatchNormalization()(x2)      

        x3 = layers.Conv3D(32, kernel_size=3, strides=2, padding='same',
                            kernel_initializer='he_normal')(x2)
        x3 = layers.LeakyReLU(alpha=0.2)(x3)  # 4
        x3 = layers.BatchNormalization()(x3)      

        x4 = layers.Conv3D(32, kernel_size=3, strides=2, padding='same',
                            kernel_initializer='he_normal')(x3)
        x4 = layers.LeakyReLU(alpha=0.2)(x4)  # 2 # 4 for 64
        x4 = layers.BatchNormalization()(x4)      

        s = 1.0  # scaling
        t = 0  # translation
        x = layers.Flatten()(x4)
        x = layers.Dense(64, activation='relu')(x)  # 4*4*32
        x = layers.Dense(12, kernel_initializer='zeros',
                         bias_initializer=tf.constant_initializer([s,0,0,t,0,s,0,t,0,0,s,t]), name='theta')(x)
        
        
        nb, _ = tf.shape(x)
        self.theta = tf.reshape(x, [nb, 3, 4])
        grid = regular_grid_3d(d, h, w)
        grid_new = grid_transform_3d(self.theta, grid)
        grid_new = tf.clip_by_value(grid_new, -1, 1)
        
        moved = grid_sample_3d(moving, grid_new, name='moved')
        moved_gt = grid_sample_3d(moving_gt, grid_new, name='moved_gt')
        
        model = tf.keras.Model(inputs={'moving': moving, 'static': static, 'moving_gt': moving_gt},
                                outputs={'moved': moved, 'moved_gt': moved_gt}, name='AffineNet')
        
        model.compile(optimizer=optimizer, loss=loss, metrics=metrics,
                      loss_weights=loss_weights)
        
        self.model = model
        
#     def theta_get(self):
#         return model.get_layer('theta')

    def compile(self, optimizer='adam', loss=None, metrics=None,
                loss_weights=None):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics,
                           loss_weights=loss_weights)

    def summary(self):
        return self.model.summary()

    def fit(self, x=None, y=None, batch_size=None, epochs=1, verbose=1,
            callbacks=None, validation_split=0.0, validation_data=None,
            shuffle=True, initial_epoch=0, steps_per_epoch=None,
            validation_steps=None, validation_batch_size=None,
            validation_freq=1, max_queue_size=10, workers=1,
            use_multiprocessing=False):
        return self.model.fit(x=x, y=y, batch_size=batch_size,
                              epochs=epochs, verbose=verbose,
                              callbacks=callbacks,
                              validation_split=validation_split,
                              validation_data=validation_data, shuffle=shuffle,
                              initial_epoch=initial_epoch,
                              steps_per_epoch=steps_per_epoch,
                              validation_steps=validation_steps,
                              validation_batch_size=validation_batch_size,
                              validation_freq=validation_freq,
                              max_queue_size=max_queue_size, workers=workers,
                              use_multiprocessing=use_multiprocessing)

    def evaluate(self, x=None, y=None, batch_size=None, verbose=1,
                 steps=None, callbacks=None, max_queue_size=10, workers=1,
                 use_multiprocessing=False, return_dict=False):
        return self.model.evaluate(x=x, y=y, batch_size=batch_size,
                                   verbose=verbose, steps=steps,
                                   callbacks=callbacks,
                                   max_queue_size=max_queue_size,
                                   workers=workers,
                                   use_multiprocessing=use_multiprocessing,
                                   return_dict=return_dict)
    
    def predict(self, x, batch_size=None, verbose=0,
                steps=None, callbacks=None, max_queue_size=10, workers=1,
                use_multiprocessing=False):
        return self.model.predict(x=x, batch_size=batch_size,
                                  verbose=verbose, steps=steps,
                                  callbacks=callbacks,
                                  max_queue_size=max_queue_size,
                                  workers=workers,
                                  use_multiprocessing=use_multiprocessing)
    def save_weights(self, filepath, overwrite=True):
        self.model.save_weights(filepath=filepath, overwrite=overwrite, save_format=None)

    def load_weights(self, filepath):
        self.model.load_weights(filepath)
    
class RegistrationDataLoader(tf.keras.utils.Sequence):
    def __init__(self, moving, static, moving_gt, batch_size=8, shuffle=False):
        """Data loader object that fetches and preprocess batches of images 
        for real-time data feeding to the model.

        Currently supports only numpy arrays as input.
    
        Parameters
        ----------
        moving : ndarray, shape (N, ..., C)
            An array of all the moving images. N is the number of images.
        static : ndarray, shape (1, ..., C)
            The static image.

        """
        self.moving = moving
        self.static = static
        self.moving_gt = moving_gt
        
        self.batch_size = batch_size
        self.shuffle = shuffle

        if self.shuffle:
            np.random.shuffle(self.moving)

    def __len__(self):
        return math.ceil(len(self.moving) / self.batch_size)

    def __getitem__(self, idx):
        moving = self.moving[idx * self.batch_size: (idx+1) * self.batch_size]
        moving_gt = self.moving_gt[idx * self.batch_size: (idx+1) * self.batch_size]
        static = np.repeat(self.static, repeats=moving.shape[0], axis=0)
        
        return {'moving': moving, 'static': static, 'moving_gt': moving_gt}, static  # input and output

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.moving)

# %%
filename4 = "./BTCV_Data/40_13labelgt.nii.gz"
static_gt = nib.load(filename4).get_fdata()
static_gt = static_gt.astype(np.float32)

def gt_dice_loss_():
    
    def dice_loss(y_pred,y_true, smooth=0):
        global static_gt
        
        y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=12)[..., 1:])
        y_pred_f = K.flatten(static_gt[...,1:])
        intersect = K.sum(y_true_f * y_pred_f, axis=-1)
        denom = K.sum(y_true_f + y_pred_f, axis=-1)

        return 1 - K.mean((2. * intersect / (denom + smooth)))
    
    return dice_loss

# %%
def mse_loss_():
    
    def mse_loss(y_true,y_pred, sigma=1.0):
        return 1.0 / (sigma**2) * K.mean(K.square(y_true - y_pred))
    
    return mse_loss

# %%
def grid_transform_3d(theta, grid):
    nb = tf.shape(theta)[0]
    nd, nh, nw, _ = tf.shape(grid)

    i = grid[..., 0] # d, h, w
    j = grid[..., 1]
    k = grid[..., 2]

    i_flat = tf.reshape(i, shape=[-1])
    j_flat = tf.reshape(j, shape=[-1])
    k_flat = tf.reshape(k, shape=[-1])

    ones = tf.ones_like(i_flat)

    grid_flat = tf.stack([i_flat, j_flat, k_flat, ones])
    grid_flat = tf.expand_dims(grid_flat, axis=0)
    grid_flat = tf.tile(grid_flat, tf.stack([nb, 1, 1]))  # n, 4, d*h*w

    # 2d 2x3; 3d 3x4
    theta = tf.cast(theta, 'float32')
    grid_flat = tf.cast(grid_flat, 'float32')
    grid_new = tf.matmul(theta, grid_flat)  # n, 3, d*h*w
    
    grid_new = tf.transpose(grid_new, perm=[0,2,1])
    grid_new = tf.reshape(grid_new, [nb, nd, nh, nw, 3])

    return grid_new

# %%
batch_size = 1
epochs = 100
lr = 0.0001  # learning rate
input_shape = (64, 128, 128)

# %%
# filename = "./mix_data/mixed_affine.nii.gz"
# filename2 = "./static_data_exis/7.nii.gz"
filename = "./BTCV_Data/resize_exis_stack.nii.gz"
filename2 = "./BTCV_Data/static_exis/40.nii.gz"
# filename3 = "./chaos_train_voxel/gt_resize/24.nii.gz"

data = nib.load(filename).get_fdata()
static = nib.load(filename2).get_fdata()

min_value = np.min(data)
max_value = np.max(data)

data = (data-min_value) / (max_value-min_value)
print(min_value)
print(max_value)

filename3 = "./BTCV_Data/resize_exis_stack_gt.nii.gz"
# filename4 = "./BTCV_Data/static_exis/40.nii.gz"
# filename3 = "./chaos_train_voxel/gt_resize/24.nii.gz"

data_gt = nib.load(filename3).get_fdata()
# static_gt = nib.load(filename4).get_fdata()

x_train = data[:26, ...][..., None]
x_train = x_train.astype(np.float32) 
x_test = data[26:, ...][..., None]
x_test = x_test.astype(np.float32)
x_sample = data[0:30, ...].copy()  # some images to visualize results

static = (static-min_value) / (max_value-min_value)
static = static[None, ..., None]
static = static.astype(np.float32)

gt_train = data_gt[:26, ...][..., None]
gt_train = gt_train.astype(np.float32) 
gt_test = data_gt[26:, ...][..., None]
gt_test = gt_test.astype(np.float32)
gt_sample = data_gt[0:30, ...].copy()

print('Train: ', x_train.shape) 
print('Test: ', x_test.shape)
print('Sample: ', x_sample.shape)
print('Static: ', static.shape)
print('GT_Train: ', gt_train.shape) 
print('GT_Test: ', gt_test.shape)


train_loader = RegistrationDataLoader(x_train, static, gt_train, batch_size=batch_size,
                                      shuffle=False)
test_loader = RegistrationDataLoader(x_test, static, gt_test, batch_size=batch_size,
                                     shuffle=False)
sample_loader = RegistrationDataLoader(x_sample, static, gt_sample, shuffle=False)
# Out:
# -3024.0
# 3095.0
# Train:  (26, 64, 128, 128, 1)
# Test:  (4, 64, 128, 128, 1)
# Sample:  (30, 64, 128, 128)
# Static:  (1, 64, 128, 128, 1)
# GT_Train:  (26, 64, 128, 128, 1)
# GT_Test:  (4, 64, 128, 128, 1)

# %%
ncc_loss = local_normalized_cross_correlation_loss()
gt_dice_loss = gt_dice_loss_()
mse_loss = mse_loss_()

# Map model outputs to the loss functions and loss weights
loss_weights = {'moved': 0.5, 'moved_gt':0.5}
losses = {'moved': mse_loss, 'moved_gt': gt_dice_loss}

optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

model = AffineNet(input_shape=input_shape, optimizer=optimizer,
                    loss=losses, loss_weights=loss_weights)

# %%
checkpoint_path = "./Affinecheck/0826_1cp.ckpt"
model.load_weights(checkpoint_path)

# %%
import tensorflow

early_stop = tensorflow.keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=250, restore_best_weights=True) 
checkpoint_path = "./Affinecheck/0826_4cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                   save_weights_only=True,
                                   verbose=1)# Train the model with the new callback

# %%
hist = model.fit(train_loader, epochs=epochs, validation_data=test_loader, callbacks=[cp_callback, early_stop])
# Out:
# Epoch 1/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 00001: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 4s 161ms/step - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9950 - val_loss: 0.5141 - val_tf_op_layer_moved_8_loss: 0.0333 - val_tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 2/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5223 - tf_op_layer_moved_8_loss: 0.0490 - tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 00002: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5223 - tf_op_layer_moved_8_loss: 0.0490 - tf_op_layer_moved_gt_8_loss: 0.9956 - val_loss: 0.5147 - val_tf_op_layer_moved_8_loss: 0.0346 - val_tf_op_layer_moved_gt_8_loss: 0.9947
# Epoch 3/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00003: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5145 - val_tf_op_layer_moved_8_loss: 0.0339 - val_tf_op_layer_moved_gt_8_loss: 0.9951
# Epoch 4/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0496 - tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 00004: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0496 - tf_op_layer_moved_gt_8_loss: 0.9956 - val_loss: 0.5148 - val_tf_op_layer_moved_8_loss: 0.0349 - val_tf_op_layer_moved_gt_8_loss: 0.9947
# Epoch 5/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0496 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00005: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0496 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5145 - val_tf_op_layer_moved_8_loss: 0.0343 - val_tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 6/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0495 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00006: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 89ms/step - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0495 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5140 - val_tf_op_layer_moved_8_loss: 0.0333 - val_tf_op_layer_moved_gt_8_loss: 0.9946
# Epoch 7/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 00007: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 91ms/step - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9958 - val_loss: 0.5142 - val_tf_op_layer_moved_8_loss: 0.0336 - val_tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 8/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5227 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 00008: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 0.5227 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9960 - val_loss: 0.5143 - val_tf_op_layer_moved_8_loss: 0.0337 - val_tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 9/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5225 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00009: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 89ms/step - loss: 0.5225 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5144 - val_tf_op_layer_moved_8_loss: 0.0336 - val_tf_op_layer_moved_gt_8_loss: 0.9951
# Epoch 10/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5229 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9964
# Epoch 00010: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5229 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9964 - val_loss: 0.5147 - val_tf_op_layer_moved_8_loss: 0.0335 - val_tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 11/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5228 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9964
# Epoch 00011: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5228 - tf_op_layer_moved_8_loss: 0.0493 - tf_op_layer_moved_gt_8_loss: 0.9964 - val_loss: 0.5146 - val_tf_op_layer_moved_8_loss: 0.0342 - val_tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 12/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 00012: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9959 - val_loss: 0.5145 - val_tf_op_layer_moved_8_loss: 0.0328 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 13/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0489 - tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 00013: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0489 - tf_op_layer_moved_gt_8_loss: 0.9959 - val_loss: 0.5139 - val_tf_op_layer_moved_8_loss: 0.0329 - val_tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 14/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5222 - tf_op_layer_moved_8_loss: 0.0491 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00014: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5222 - tf_op_layer_moved_8_loss: 0.0491 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5145 - val_tf_op_layer_moved_8_loss: 0.0333 - val_tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 15/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5229 - tf_op_layer_moved_8_loss: 0.0495 - tf_op_layer_moved_gt_8_loss: 0.9962
# Epoch 00015: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5229 - tf_op_layer_moved_8_loss: 0.0495 - tf_op_layer_moved_gt_8_loss: 0.9962 - val_loss: 0.5133 - val_tf_op_layer_moved_8_loss: 0.0316 - val_tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 16/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9945
# Epoch 00016: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9945 - val_loss: 0.5139 - val_tf_op_layer_moved_8_loss: 0.0330 - val_tf_op_layer_moved_gt_8_loss: 0.9947
# Epoch 17/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0489 - tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 00017: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0489 - tf_op_layer_moved_gt_8_loss: 0.9950 - val_loss: 0.5132 - val_tf_op_layer_moved_8_loss: 0.0311 - val_tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 18/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5223 - tf_op_layer_moved_8_loss: 0.0487 - tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 00018: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5223 - tf_op_layer_moved_8_loss: 0.0487 - tf_op_layer_moved_gt_8_loss: 0.9960 - val_loss: 0.5141 - val_tf_op_layer_moved_8_loss: 0.0327 - val_tf_op_layer_moved_gt_8_loss: 0.9955
# Epoch 19/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 00019: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9956 - val_loss: 0.5141 - val_tf_op_layer_moved_8_loss: 0.0320 - val_tf_op_layer_moved_gt_8_loss: 0.9962
# Epoch 20/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5222 - tf_op_layer_moved_8_loss: 0.0490 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00020: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 0.5222 - tf_op_layer_moved_8_loss: 0.0490 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5153 - val_tf_op_layer_moved_8_loss: 0.0339 - val_tf_op_layer_moved_gt_8_loss: 0.9967
# Epoch 21/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5229 - tf_op_layer_moved_8_loss: 0.0490 - tf_op_layer_moved_gt_8_loss: 0.9968
# Epoch 00021: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5229 - tf_op_layer_moved_8_loss: 0.0490 - tf_op_layer_moved_gt_8_loss: 0.9968 - val_loss: 0.5138 - val_tf_op_layer_moved_8_loss: 0.0313 - val_tf_op_layer_moved_gt_8_loss: 0.9963
# Epoch 22/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9947
# Epoch 00022: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9947 - val_loss: 0.5136 - val_tf_op_layer_moved_8_loss: 0.0326 - val_tf_op_layer_moved_gt_8_loss: 0.9947
# Epoch 23/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9955
# Epoch 00023: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9955 - val_loss: 0.5133 - val_tf_op_layer_moved_8_loss: 0.0305 - val_tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 24/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5222 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9962
# Epoch 00024: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5222 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9962 - val_loss: 0.5151 - val_tf_op_layer_moved_8_loss: 0.0346 - val_tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 25/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5232 - tf_op_layer_moved_8_loss: 0.0499 - tf_op_layer_moved_gt_8_loss: 0.9964
# Epoch 00025: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 0.5232 - tf_op_layer_moved_8_loss: 0.0499 - tf_op_layer_moved_gt_8_loss: 0.9964 - val_loss: 0.5148 - val_tf_op_layer_moved_8_loss: 0.0348 - val_tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 26/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5223 - tf_op_layer_moved_8_loss: 0.0489 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00026: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5223 - tf_op_layer_moved_8_loss: 0.0489 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5141 - val_tf_op_layer_moved_8_loss: 0.0326 - val_tf_op_layer_moved_gt_8_loss: 0.9955
# Epoch 27/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9947
# Epoch 00027: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9947 - val_loss: 0.5136 - val_tf_op_layer_moved_8_loss: 0.0325 - val_tf_op_layer_moved_gt_8_loss: 0.9947
# Epoch 28/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0485 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00028: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0485 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5131 - val_tf_op_layer_moved_8_loss: 0.0312 - val_tf_op_layer_moved_gt_8_loss: 0.9951
# Epoch 29/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9955
# Epoch 00029: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9955 - val_loss: 0.5129 - val_tf_op_layer_moved_8_loss: 0.0302 - val_tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 30/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9952
# Epoch 00030: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9952 - val_loss: 0.5136 - val_tf_op_layer_moved_8_loss: 0.0316 - val_tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 31/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5225 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 00031: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5225 - tf_op_layer_moved_8_loss: 0.0494 - tf_op_layer_moved_gt_8_loss: 0.9956 - val_loss: 0.5149 - val_tf_op_layer_moved_8_loss: 0.0347 - val_tf_op_layer_moved_gt_8_loss: 0.9951
# Epoch 32/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 00032: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9960 - val_loss: 0.5139 - val_tf_op_layer_moved_8_loss: 0.0325 - val_tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 33/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0476 - tf_op_layer_moved_gt_8_loss: 0.9945
# Epoch 00033: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0476 - tf_op_layer_moved_gt_8_loss: 0.9945 - val_loss: 0.5135 - val_tf_op_layer_moved_8_loss: 0.0312 - val_tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 34/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0495 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00034: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5226 - tf_op_layer_moved_8_loss: 0.0495 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5138 - val_tf_op_layer_moved_8_loss: 0.0314 - val_tf_op_layer_moved_gt_8_loss: 0.9962
# Epoch 35/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 00035: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9961 - val_loss: 0.5141 - val_tf_op_layer_moved_8_loss: 0.0324 - val_tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 36/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0486 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00036: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0486 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5131 - val_tf_op_layer_moved_8_loss: 0.0302 - val_tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 37/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00037: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5160 - val_tf_op_layer_moved_8_loss: 0.0349 - val_tf_op_layer_moved_gt_8_loss: 0.9970
# Epoch 38/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5228 - tf_op_layer_moved_8_loss: 0.0498 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00038: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5228 - tf_op_layer_moved_8_loss: 0.0498 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5137 - val_tf_op_layer_moved_8_loss: 0.0320 - val_tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 39/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0475 - tf_op_layer_moved_gt_8_loss: 0.9951
# Epoch 00039: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0475 - tf_op_layer_moved_gt_8_loss: 0.9951 - val_loss: 0.5128 - val_tf_op_layer_moved_8_loss: 0.0310 - val_tf_op_layer_moved_gt_8_loss: 0.9946
# Epoch 40/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0479 - tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 00040: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0479 - tf_op_layer_moved_gt_8_loss: 0.9959 - val_loss: 0.5134 - val_tf_op_layer_moved_8_loss: 0.0308 - val_tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 41/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00041: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5132 - val_tf_op_layer_moved_8_loss: 0.0305 - val_tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 42/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5216 - tf_op_layer_moved_8_loss: 0.0476 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00042: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5216 - tf_op_layer_moved_8_loss: 0.0476 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5136 - val_tf_op_layer_moved_8_loss: 0.0323 - val_tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 43/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0486 - tf_op_layer_moved_gt_8_loss: 0.9962
# Epoch 00043: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0486 - tf_op_layer_moved_gt_8_loss: 0.9962 - val_loss: 0.5132 - val_tf_op_layer_moved_8_loss: 0.0310 - val_tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 44/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00044: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5140 - val_tf_op_layer_moved_8_loss: 0.0319 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 45/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5221 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9955
# Epoch 00045: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5221 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9955 - val_loss: 0.5134 - val_tf_op_layer_moved_8_loss: 0.0307 - val_tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 46/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 00046: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9949 - val_loss: 0.5149 - val_tf_op_layer_moved_8_loss: 0.0325 - val_tf_op_layer_moved_gt_8_loss: 0.9973
# Epoch 47/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00047: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 85ms/step - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5128 - val_tf_op_layer_moved_8_loss: 0.0325 - val_tf_op_layer_moved_gt_8_loss: 0.9930
# Epoch 48/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00048: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5152 - val_tf_op_layer_moved_8_loss: 0.0351 - val_tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 49/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 00049: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 85ms/step - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0488 - tf_op_layer_moved_gt_8_loss: 0.9948 - val_loss: 0.5136 - val_tf_op_layer_moved_8_loss: 0.0324 - val_tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 50/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0478 - tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 00050: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0478 - tf_op_layer_moved_gt_8_loss: 0.9949 - val_loss: 0.5147 - val_tf_op_layer_moved_8_loss: 0.0333 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 51/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0487 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00051: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5220 - tf_op_layer_moved_8_loss: 0.0487 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5133 - val_tf_op_layer_moved_8_loss: 0.0307 - val_tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 52/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0472 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00052: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0472 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5136 - val_tf_op_layer_moved_8_loss: 0.0320 - val_tf_op_layer_moved_gt_8_loss: 0.9952
# Epoch 53/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0479 - tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 00053: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0479 - tf_op_layer_moved_gt_8_loss: 0.9948 - val_loss: 0.5128 - val_tf_op_layer_moved_8_loss: 0.0308 - val_tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 54/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 00054: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9956 - val_loss: 0.5137 - val_tf_op_layer_moved_8_loss: 0.0307 - val_tf_op_layer_moved_gt_8_loss: 0.9966
# Epoch 55/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5212 - tf_op_layer_moved_8_loss: 0.0470 - tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 00055: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5212 - tf_op_layer_moved_8_loss: 0.0470 - tf_op_layer_moved_gt_8_loss: 0.9954 - val_loss: 0.5129 - val_tf_op_layer_moved_8_loss: 0.0291 - val_tf_op_layer_moved_gt_8_loss: 0.9966
# Epoch 56/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5207 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9946
# Epoch 00056: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5207 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9946 - val_loss: 0.5132 - val_tf_op_layer_moved_8_loss: 0.0294 - val_tf_op_layer_moved_gt_8_loss: 0.9970
# Epoch 57/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 00057: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0481 - tf_op_layer_moved_gt_8_loss: 0.9949 - val_loss: 0.5129 - val_tf_op_layer_moved_8_loss: 0.0311 - val_tf_op_layer_moved_gt_8_loss: 0.9946
# Epoch 58/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5207 - tf_op_layer_moved_8_loss: 0.0473 - tf_op_layer_moved_gt_8_loss: 0.9941
# Epoch 00058: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5207 - tf_op_layer_moved_8_loss: 0.0473 - tf_op_layer_moved_gt_8_loss: 0.9941 - val_loss: 0.5122 - val_tf_op_layer_moved_8_loss: 0.0288 - val_tf_op_layer_moved_gt_8_loss: 0.9955
# Epoch 59/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5203 - tf_op_layer_moved_8_loss: 0.0462 - tf_op_layer_moved_gt_8_loss: 0.9943
# Epoch 00059: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5203 - tf_op_layer_moved_8_loss: 0.0462 - tf_op_layer_moved_gt_8_loss: 0.9943 - val_loss: 0.5133 - val_tf_op_layer_moved_8_loss: 0.0317 - val_tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 60/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5205 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9943
# Epoch 00060: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5205 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9943 - val_loss: 0.5129 - val_tf_op_layer_moved_8_loss: 0.0300 - val_tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 61/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0472 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00061: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0472 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5127 - val_tf_op_layer_moved_8_loss: 0.0300 - val_tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 62/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0478 - tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 00062: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0478 - tf_op_layer_moved_gt_8_loss: 0.9949 - val_loss: 0.5143 - val_tf_op_layer_moved_8_loss: 0.0318 - val_tf_op_layer_moved_gt_8_loss: 0.9968
# Epoch 63/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5207 - tf_op_layer_moved_8_loss: 0.0470 - tf_op_layer_moved_gt_8_loss: 0.9943
# Epoch 00063: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5207 - tf_op_layer_moved_8_loss: 0.0470 - tf_op_layer_moved_gt_8_loss: 0.9943 - val_loss: 0.5127 - val_tf_op_layer_moved_8_loss: 0.0280 - val_tf_op_layer_moved_gt_8_loss: 0.9975
# Epoch 64/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5208 - tf_op_layer_moved_8_loss: 0.0465 - tf_op_layer_moved_gt_8_loss: 0.9952
# Epoch 00064: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5208 - tf_op_layer_moved_8_loss: 0.0465 - tf_op_layer_moved_gt_8_loss: 0.9952 - val_loss: 0.5120 - val_tf_op_layer_moved_8_loss: 0.0279 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 65/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9944
# Epoch 00065: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9944 - val_loss: 0.5120 - val_tf_op_layer_moved_8_loss: 0.0273 - val_tf_op_layer_moved_gt_8_loss: 0.9966
# Epoch 66/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0465 - tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 00066: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0465 - tf_op_layer_moved_gt_8_loss: 0.9958 - val_loss: 0.5118 - val_tf_op_layer_moved_8_loss: 0.0279 - val_tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 67/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5205 - tf_op_layer_moved_8_loss: 0.0463 - tf_op_layer_moved_gt_8_loss: 0.9946
# Epoch 00067: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5205 - tf_op_layer_moved_8_loss: 0.0463 - tf_op_layer_moved_gt_8_loss: 0.9946 - val_loss: 0.5132 - val_tf_op_layer_moved_8_loss: 0.0296 - val_tf_op_layer_moved_gt_8_loss: 0.9967
# Epoch 68/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9964
# Epoch 00068: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5224 - tf_op_layer_moved_8_loss: 0.0484 - tf_op_layer_moved_gt_8_loss: 0.9964 - val_loss: 0.5128 - val_tf_op_layer_moved_8_loss: 0.0289 - val_tf_op_layer_moved_gt_8_loss: 0.9966
# Epoch 69/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 00069: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9956 - val_loss: 0.5134 - val_tf_op_layer_moved_8_loss: 0.0290 - val_tf_op_layer_moved_gt_8_loss: 0.9979
# Epoch 70/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0475 - tf_op_layer_moved_gt_8_loss: 0.9964
# Epoch 00070: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5219 - tf_op_layer_moved_8_loss: 0.0475 - tf_op_layer_moved_gt_8_loss: 0.9964 - val_loss: 0.5114 - val_tf_op_layer_moved_8_loss: 0.0260 - val_tf_op_layer_moved_gt_8_loss: 0.9969
# Epoch 71/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5209 - tf_op_layer_moved_8_loss: 0.0460 - tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 00071: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 85ms/step - loss: 0.5209 - tf_op_layer_moved_8_loss: 0.0460 - tf_op_layer_moved_gt_8_loss: 0.9959 - val_loss: 0.5131 - val_tf_op_layer_moved_8_loss: 0.0287 - val_tf_op_layer_moved_gt_8_loss: 0.9975
# Epoch 72/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0461 - tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 00072: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0461 - tf_op_layer_moved_gt_8_loss: 0.9959 - val_loss: 0.5114 - val_tf_op_layer_moved_8_loss: 0.0264 - val_tf_op_layer_moved_gt_8_loss: 0.9963
# Epoch 73/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5206 - tf_op_layer_moved_8_loss: 0.0465 - tf_op_layer_moved_gt_8_loss: 0.9946
# Epoch 00073: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5206 - tf_op_layer_moved_8_loss: 0.0465 - tf_op_layer_moved_gt_8_loss: 0.9946 - val_loss: 0.5133 - val_tf_op_layer_moved_8_loss: 0.0305 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 74/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 00074: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5217 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9956 - val_loss: 0.5109 - val_tf_op_layer_moved_8_loss: 0.0258 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 75/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5199 - tf_op_layer_moved_8_loss: 0.0452 - tf_op_layer_moved_gt_8_loss: 0.9946
# Epoch 00075: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5199 - tf_op_layer_moved_8_loss: 0.0452 - tf_op_layer_moved_gt_8_loss: 0.9946 - val_loss: 0.5135 - val_tf_op_layer_moved_8_loss: 0.0308 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 76/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00076: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0477 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5110 - val_tf_op_layer_moved_8_loss: 0.0260 - val_tf_op_layer_moved_gt_8_loss: 0.9959
# Epoch 77/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0464 - tf_op_layer_moved_gt_8_loss: 0.9944
# Epoch 00077: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0464 - tf_op_layer_moved_gt_8_loss: 0.9944 - val_loss: 0.5135 - val_tf_op_layer_moved_8_loss: 0.0319 - val_tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 78/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5225 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9968
# Epoch 00078: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5225 - tf_op_layer_moved_8_loss: 0.0482 - tf_op_layer_moved_gt_8_loss: 0.9968 - val_loss: 0.5128 - val_tf_op_layer_moved_8_loss: 0.0292 - val_tf_op_layer_moved_gt_8_loss: 0.9964
# Epoch 79/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5205 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9944
# Epoch 00079: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5205 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9944 - val_loss: 0.5123 - val_tf_op_layer_moved_8_loss: 0.0285 - val_tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 80/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0459 - tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 00080: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0459 - tf_op_layer_moved_gt_8_loss: 0.9949 - val_loss: 0.5121 - val_tf_op_layer_moved_8_loss: 0.0281 - val_tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 81/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0479 - tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 00081: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0479 - tf_op_layer_moved_gt_8_loss: 0.9948 - val_loss: 0.5098 - val_tf_op_layer_moved_8_loss: 0.0242 - val_tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 82/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5206 - tf_op_layer_moved_8_loss: 0.0469 - tf_op_layer_moved_gt_8_loss: 0.9942
# Epoch 00082: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 85ms/step - loss: 0.5206 - tf_op_layer_moved_8_loss: 0.0469 - tf_op_layer_moved_gt_8_loss: 0.9942 - val_loss: 0.5123 - val_tf_op_layer_moved_8_loss: 0.0315 - val_tf_op_layer_moved_gt_8_loss: 0.9930
# Epoch 83/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5206 - tf_op_layer_moved_8_loss: 0.0475 - tf_op_layer_moved_gt_8_loss: 0.9938
# Epoch 00083: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5206 - tf_op_layer_moved_8_loss: 0.0475 - tf_op_layer_moved_gt_8_loss: 0.9938 - val_loss: 0.5120 - val_tf_op_layer_moved_8_loss: 0.0284 - val_tf_op_layer_moved_gt_8_loss: 0.9956
# Epoch 84/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0474 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00084: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 88ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0474 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5107 - val_tf_op_layer_moved_8_loss: 0.0254 - val_tf_op_layer_moved_gt_8_loss: 0.9960
# Epoch 85/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0463 - tf_op_layer_moved_gt_8_loss: 0.9945
# Epoch 00085: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0463 - tf_op_layer_moved_gt_8_loss: 0.9945 - val_loss: 0.5103 - val_tf_op_layer_moved_8_loss: 0.0254 - val_tf_op_layer_moved_gt_8_loss: 0.9951
# Epoch 86/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0458 - tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 00086: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5204 - tf_op_layer_moved_8_loss: 0.0458 - tf_op_layer_moved_gt_8_loss: 0.9950 - val_loss: 0.5132 - val_tf_op_layer_moved_8_loss: 0.0298 - val_tf_op_layer_moved_gt_8_loss: 0.9967
# Epoch 87/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5208 - tf_op_layer_moved_8_loss: 0.0472 - tf_op_layer_moved_gt_8_loss: 0.9945
# Epoch 00087: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5208 - tf_op_layer_moved_8_loss: 0.0472 - tf_op_layer_moved_gt_8_loss: 0.9945 - val_loss: 0.5096 - val_tf_op_layer_moved_8_loss: 0.0255 - val_tf_op_layer_moved_gt_8_loss: 0.9936
# Epoch 88/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5203 - tf_op_layer_moved_8_loss: 0.0462 - tf_op_layer_moved_gt_8_loss: 0.9944
# Epoch 00088: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5203 - tf_op_layer_moved_8_loss: 0.0462 - tf_op_layer_moved_gt_8_loss: 0.9944 - val_loss: 0.5123 - val_tf_op_layer_moved_8_loss: 0.0297 - val_tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 89/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 00089: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9953 - val_loss: 0.5115 - val_tf_op_layer_moved_8_loss: 0.0282 - val_tf_op_layer_moved_gt_8_loss: 0.9948
# Epoch 90/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0467 - tf_op_layer_moved_gt_8_loss: 0.9955
# Epoch 00090: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5211 - tf_op_layer_moved_8_loss: 0.0467 - tf_op_layer_moved_gt_8_loss: 0.9955 - val_loss: 0.5111 - val_tf_op_layer_moved_8_loss: 0.0267 - val_tf_op_layer_moved_gt_8_loss: 0.9954
# Epoch 91/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0464 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00091: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0464 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5126 - val_tf_op_layer_moved_8_loss: 0.0299 - val_tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 92/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0471 - tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 00092: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5210 - tf_op_layer_moved_8_loss: 0.0471 - tf_op_layer_moved_gt_8_loss: 0.9950 - val_loss: 0.5118 - val_tf_op_layer_moved_8_loss: 0.0282 - val_tf_op_layer_moved_gt_8_loss: 0.9953
# Epoch 93/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5212 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9957
# Epoch 00093: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5212 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9957 - val_loss: 0.5138 - val_tf_op_layer_moved_8_loss: 0.0298 - val_tf_op_layer_moved_gt_8_loss: 0.9978
# Epoch 94/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9963
# Epoch 00094: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5215 - tf_op_layer_moved_8_loss: 0.0468 - tf_op_layer_moved_gt_8_loss: 0.9963 - val_loss: 0.5126 - val_tf_op_layer_moved_8_loss: 0.0302 - val_tf_op_layer_moved_gt_8_loss: 0.9951
# Epoch 95/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0470 - tf_op_layer_moved_gt_8_loss: 0.9965
# Epoch 00095: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0470 - tf_op_layer_moved_gt_8_loss: 0.9965 - val_loss: 0.5108 - val_tf_op_layer_moved_8_loss: 0.0268 - val_tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 96/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5202 - tf_op_layer_moved_8_loss: 0.0460 - tf_op_layer_moved_gt_8_loss: 0.9945
# Epoch 00096: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 85ms/step - loss: 0.5202 - tf_op_layer_moved_8_loss: 0.0460 - tf_op_layer_moved_gt_8_loss: 0.9945 - val_loss: 0.5120 - val_tf_op_layer_moved_8_loss: 0.0282 - val_tf_op_layer_moved_gt_8_loss: 0.9958
# Epoch 97/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5200 - tf_op_layer_moved_8_loss: 0.0459 - tf_op_layer_moved_gt_8_loss: 0.9940
# Epoch 00097: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5200 - tf_op_layer_moved_8_loss: 0.0459 - tf_op_layer_moved_gt_8_loss: 0.9940 - val_loss: 0.5102 - val_tf_op_layer_moved_8_loss: 0.0253 - val_tf_op_layer_moved_gt_8_loss: 0.9952
# Epoch 98/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9949
# Epoch 00098: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 87ms/step - loss: 0.5214 - tf_op_layer_moved_8_loss: 0.0480 - tf_op_layer_moved_gt_8_loss: 0.9949 - val_loss: 0.5129 - val_tf_op_layer_moved_8_loss: 0.0306 - val_tf_op_layer_moved_gt_8_loss: 0.9952
# Epoch 99/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9961
# Epoch 00099: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5213 - tf_op_layer_moved_8_loss: 0.0466 - tf_op_layer_moved_gt_8_loss: 0.9961 - val_loss: 0.5108 - val_tf_op_layer_moved_8_loss: 0.0266 - val_tf_op_layer_moved_gt_8_loss: 0.9950
# Epoch 100/100
# 26/26 [==============================] - ETA: 0s - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0471 - tf_op_layer_moved_gt_8_loss: 0.9964
# Epoch 00100: saving model to ./Affinecheck/0826_4cp.ckpt
# 26/26 [==============================] - 2s 86ms/step - loss: 0.5218 - tf_op_layer_moved_8_loss: 0.0471 - tf_op_layer_moved_gt_8_loss: 0.9964 - val_loss: 0.5128 - val_tf_op_layer_moved_8_loss: 0.0307 - val_tf_op_layer_moved_gt_8_loss: 0.9948

# %%
plt.plot(hist.history['loss'], color='red', label='Train')
plt.plot(hist.history['val_loss'], color='blue', label='Test')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper right")
plt.title('Loss vs. Epochs')
plt.show()
# plt.savefig('loss_plot.png')hist = model.fit(train_loader, epochs=epochs, validation_data=test_loader, callbacks=[cp_callback, early_stop])

# %%
model.save_weights(checkpoint_path)

# %%
checkpoint_path = "./Affinecheck/0825_2cp.ckpt"
model.load_weights(checkpoint_path)

# %%
checkpoint_path = "./Affinecheck/0826_5cp.ckpt"
model.save_weights(checkpoint_path)

# %%
output = model.predict(sample_loader)

# %%
## 간단하게 결과 보기 위한 코드 ##
output = model.predict(sample_loader)
moved = output['moved']
# deformation = output['deformation']
# moved_gt = output['moved_gt']

# moved = moved * max_value
print(moved.shape)
a = moved[0]
# b = deformation[0]
# c = moved_gt[0]

print(a.shape)
a = a.swapaxes(0,2) 
# b = b.swapaxes(0,2)
# c = c.swapaxes(0,2)
print(a.shape)

a = nib.Nifti1Image(a,None) 
# b = nib.Nifti1Image(b,None)
# c = nib.Nifti1Image(c,None)

nib.save(a,'BTCV_Data/aff_moved_0826_1.nii.gz')
# nib.save(b,'BTCV_Data/aff_deformation_0825_1.nii.gz')
# nib.save(c,'BTCV_Data/aff_gt_moved_0825_1.nii.gz')
# Out:
# (30, 64, 128, 128, 1)
# (64, 128, 128, 1)
# (128, 128, 64, 1)

# %%
f1model = Model(inputs=model.model.input, outputs=model.model.get_layer('theta').output)
theta_x = f1model.predict(sample_loader)

print(theta_x.shape)
# Out:
# (30, 12)

# %%
# Affine GT 만들기! 파일 불러와서 한번에 다 처리!##########
a = 1
j = 0
for i in range (0, 39):
    filename = "./BTCV_Data/gt_resize/" + str(a) + ".nii.gz"
    if os.path.isfile(filename):
        x = nib.load(filename).get_fdata()
        x = x.astype(np.float32)
        x = x.swapaxes(0,2)
        # print(x.shape)
        d,h,w = x.shape
        x = np.expand_dims(x,axis=0)
        x = np.expand_dims(x,axis=-1)

        grid = regular_grid_3d(d,h,w)
        nb = 1
        theta = tf.reshape(theta_x[j], [nb,3,4])

        grid_new = grid_transform_3d(theta[0], grid)
        grid_new = tf.clip_by_value(grid_new, -1, 1)


        moved = grid_sample_3d(x, grid_new)
        
        x = np.squeeze(moved[0]) 
        # print(x.shape)
        
        d,h,w = x.shape
        x_copy = x.copy()
        
        x_copy = x_copy.swapaxes(0,2)
        print(a, ":", x_copy.shape )
        savename = "./BTCV_Data/0826_affine_GT_6/" + str(a) + ".nii.gz"
        x_copy = nib.Nifti1Image(x_copy, None) 
        nib.save(x_copy,savename)
        
        j += 1
        
    a += 1
# Out:
# 1 : (128, 128, 64)
# 2 : (128, 128, 64)
# 3 : (128, 128, 64)
# 4 : (128, 128, 64)
# 5 : (128, 128, 64)
# 6 : (128, 128, 64)
# 7 : (128, 128, 64)
# 8 : (128, 128, 64)
# 9 : (128, 128, 64)
# 10 : (128, 128, 64)
# 21 : (128, 128, 64)
# 22 : (128, 128, 64)
# 23 : (128, 128, 64)
# 24 : (128, 128, 64)
# 25 : (128, 128, 64)
# 26 : (128, 128, 64)
# 27 : (128, 128, 64)
# 28 : (128, 128, 64)
# 29 : (128, 128, 64)
# 30 : (128, 128, 64)
# 31 : (128, 128, 64)
# 32 : (128, 128, 64)
# 33 : (128, 128, 64)
# 34 : (128, 128, 64)
# 35 : (128, 128, 64)
# 36 : (128, 128, 64)
# 37 : (128, 128, 64)
# 38 : (128, 128, 64)
# 39 : (128, 128, 64)

# %%
# Affine moving 만들기! 파일 불러와서 한번에 다 처리!##########
a = 1
j = 0
for i in range (0, 39):
    filename = "./BTCV_Data/1resize/" + str(a) + ".nii.gz"
    if os.path.isfile(filename):
        x = nib.load(filename).get_fdata()
        x = x.astype(np.float32)
        x = x.swapaxes(0,2)
        # print(x.shape)
        d,h,w = x.shape
        x = np.expand_dims(x,axis=0)
        x = np.expand_dims(x,axis=-1)

        grid = regular_grid_3d(d,h,w)
        nb = 1
        theta = tf.reshape(theta_x[j], [nb,3,4])

        grid_new = grid_transform_3d(theta[0], grid)
        grid_new = tf.clip_by_value(grid_new, -1, 1)


        moved = grid_sample_3d(x, grid_new)
        
        x = np.squeeze(moved[0]) 
        # print(x.shape)
        
        d,h,w = x.shape
        x_copy = x.copy()
        
        x_copy = x_copy.swapaxes(0,2)
        print(a, ":", x_copy.shape )
        savename = "./BTCV_Data/0826_affine_1/" + str(a) + ".nii.gz"
        x_copy = nib.Nifti1Image(x_copy, None) 
        nib.save(x_copy,savename)
        
        j += 1
        
    a += 1
# Out:
# 1 : (128, 128, 64)
# 2 : (128, 128, 64)
# 3 : (128, 128, 64)
# 4 : (128, 128, 64)
# 5 : (128, 128, 64)
# 6 : (128, 128, 64)
# 7 : (128, 128, 64)
# 8 : (128, 128, 64)
# 9 : (128, 128, 64)
# 10 : (128, 128, 64)
# 21 : (128, 128, 64)
# 22 : (128, 128, 64)
# 23 : (128, 128, 64)
# 24 : (128, 128, 64)
# 25 : (128, 128, 64)
# 26 : (128, 128, 64)
# 27 : (128, 128, 64)
# 28 : (128, 128, 64)
# 29 : (128, 128, 64)
# 30 : (128, 128, 64)
# 31 : (128, 128, 64)
# 32 : (128, 128, 64)
# 33 : (128, 128, 64)
# 34 : (128, 128, 64)
# 35 : (128, 128, 64)
# 36 : (128, 128, 64)
# 37 : (128, 128, 64)
# 38 : (128, 128, 64)
# 39 : (128, 128, 64)

# %%
#### GT Stack 쌓아서 저장 ####

st = []
a=1
for i in range (0, 40):
    filename = "./BTCV_Data/0826_affine_GT_1/" + str(a) + ".nii.gz"
    if os.path.isfile(filename):
        x = nib.load(filename).get_fdata()
        x = x.swapaxes(0,2)
        st.append(x)
        
        
    a+=1  
st = np.array(st)
print(st.shape)

savename = "./BTCV_Data/0826_affine_1_exis_stack_gt.nii.gz"
x = nib.Nifti1Image(st, None) 
nib.save(x, savename)
# Out:
# (29, 64, 128, 128)

# %%
#### voxel Stack 쌓아서 저장 ####

st = []
a=1
for i in range (0, 40):
    filename = "./BTCV_Data/0826_affine_1/" + str(a) + ".nii.gz"
    if os.path.isfile(filename):
        x = nib.load(filename).get_fdata()
        x = x.swapaxes(0,2)
        st.append(x)
        
        
    a+=1  
st = np.array(st)
print(st.shape)

savename = "./BTCV_Data/0826_affine_1_exis_stack.nii.gz"
x = nib.Nifti1Image(st, None) 
nib.save(x, savename)
# Out:
# (29, 64, 128, 128)

# %%
### Affine 된 GT들을 Nearest Neighborhood Interpolation 진행 ###
aaa = 1
for i in range (0, 39):
    filename = "./BTCV_Data/gt_affine/" + str(aaa) + ".nii.gz"
    if os.path.isfile(filename):
        x = nib.load(filename).get_fdata()
        x = x.astype(np.float32)
        w, h, d = x.shape

        while(1):
            change = x
            ff = 0
            for i in range(1,w-1):
                for j in range(1,h-1):
                    for k in range(1, d):
                        buffer = float(x[i][j][k]) 
                        if (buffer.is_integer() is False):
                            ff += 1
                            #output = [abs(x[i][j][k]-x[i-1][j][k]), abs(x[i][j][k]-x[i+1][j][k]), abs(x[i][j][k]-x[i][j-1][k]), abs(x[i][j][k]-x[i][j+1][k]),
                            #          abs(x[i][j][k]-x[i][j][k-1]), abs(x[i][j][k]-x[i][j][k+1])] 
                            #output_ch = [x[i-1][j][k], x[i+1][j][k], x[i][j-1][k], x[i][j+1][k], x[i][j][k-1], x[i][j][k+1]] 
                            output = []
                            output_ch = []
                            if (float(x[i-1][j][k]).is_integer() is True):
                                output_ch.append(x[i-1][j][k])
                                output.append(abs(x[i][j][k]-x[i-1][j][k]))
                            if (float(x[i+1][j][k]).is_integer() is True):
                                output_ch.append(x[i+1][j][k])
                                output.append(abs(x[i][j][k]-x[i+1][j][k]))
                            if (float(x[i][j-1][k]).is_integer() is True):
                                output_ch.append(x[i][j-1][k])
                                output.append(abs(x[i][j][k]-x[i][j-1][k]))
                            if (float(x[i][j+1][k]).is_integer() is True):
                                output_ch.append(x[i][j+1][k])
                                output.append(abs(x[i][j][k]-x[i][j+1][k]))
                            if (float(x[i][j][k-1]).is_integer() is True):
                                output_ch.append(x[i][j][k-1])
                                output.append(abs(x[i][j][k]-x[i][j][k-1]))
                            if (k < d-1):
                                if (float(x[i][j][k+1]).is_integer() is True):
                                    output_ch.append(x[i][j][k+1])
                                    output.append(abs(x[i][j][k]-x[i+1][j][k+1]))

                            a = np.argmin(output)
                            change[i][j][k] = output_ch[a]


            x = change
            print(ff)
            if (ff==0):
                break


        savename = "./BTCV_Data/gt_change/" + str(aaa) + ".nii.gz"
        x_copy = nib.Nifti1Image(change, None) 
        nib.save(x_copy,savename)
        
    aaa += 1
# Out:
# 46951
# 0
# 6887
# 0
# 11667
# 0
# 14537
# 0
# 27865
# 0
# 56714
# 0
# 20273
# 0
# 6821
# 0
# 29405
# 0
# 10129
# 0
# 17753
# 0
# 20340
# 0
# 10671
# 0
# 35939
# 0
# 14067
# 0
# 18202
# 0
# 23819
# 0
# 21335
# 0
# 52228
# 0
# 21556
# 0
# 59585
# 0
# 33186
# 0
# 21253
# 0
# 16105
# 0
# 13440
# 0
# 40488
# 0
# 20483
# 0
# 22099
# 0
# 6389
# 0

# %%
### Affine 된 GT들을 Nearest Neighborhood Interpolation 진행 ###
aaa = 1
for i in range (0, 39):
    filename = "./BTCV_Data/gt_voxelmorph_r1/" + str(aaa) + ".nii.gz"
    if os.path.isfile(filename):
        x = nib.load(filename).get_fdata()
        x = x.astype(np.float32)
        w, h, d = x.shape

        while(1):
            change = x
            ff = 0
            for i in range(1,w-1):
                for j in range(1,h-1):
                    for k in range(1, d):
                        buffer = float(x[i][j][k]) 
                        if (buffer.is_integer() is False):
                            ff += 1
                            #output = [abs(x[i][j][k]-x[i-1][j][k]), abs(x[i][j][k]-x[i+1][j][k]), abs(x[i][j][k]-x[i][j-1][k]), abs(x[i][j][k]-x[i][j+1][k]),
                            #          abs(x[i][j][k]-x[i][j][k-1]), abs(x[i][j][k]-x[i][j][k+1])] 
                            #output_ch = [x[i-1][j][k], x[i+1][j][k], x[i][j-1][k], x[i][j+1][k], x[i][j][k-1], x[i][j][k+1]] 
                            output = []
                            output_ch = []
                            if (float(x[i-1][j][k]).is_integer() is True):
                                output_ch.append(x[i-1][j][k])
                                output.append(abs(x[i][j][k]-x[i-1][j][k]))
                            if (float(x[i+1][j][k]).is_integer() is True):
                                output_ch.append(x[i+1][j][k])
                                output.append(abs(x[i][j][k]-x[i+1][j][k]))
                            if (float(x[i][j-1][k]).is_integer() is True):
                                output_ch.append(x[i][j-1][k])
                                output.append(abs(x[i][j][k]-x[i][j-1][k]))
                            if (float(x[i][j+1][k]).is_integer() is True):
                                output_ch.append(x[i][j+1][k])
                                output.append(abs(x[i][j][k]-x[i][j+1][k]))
                            if (float(x[i][j][k-1]).is_integer() is True):
                                output_ch.append(x[i][j][k-1])
                                output.append(abs(x[i][j][k]-x[i][j][k-1]))
                            if (k < d-1):
                                if (float(x[i][j][k+1]).is_integer() is True):
                                    output_ch.append(x[i][j][k+1])
                                    output.append(abs(x[i][j][k]-x[i+1][j][k+1]))

                            a = np.argmin(output)
                            change[i][j][k] = output_ch[a]


            x = change
            print(ff)
            if (ff==0):
                break


        savename = "./BTCV_Data/gt_change_vox_r1/" + str(aaa) + ".nii.gz"
        x_copy = nib.Nifti1Image(change, None) 
        nib.save(x_copy,savename)
        
    aaa += 1
# Out:
# 39662
# 0
# 5259
# 0
# 6482
# 0
# 22449
# 0
# 22136
# 0
# 73404
# 0
# 25133
# 0
# 8954
# 0
# 76138
# 0
# 18733
# 0
# 13866
# 0
# 82020
# 0
# 10557
# 0
# 31501
# 0
# 15750
# 0
# 39262
# 0
# 79475
# 0
# 65092
# 0
# 65290
# 0
# 19339
# 0
# 79196
# 0
# 33656
# 0
# 64375
# 0
# 10551
# 0
# 64693
# 0
# 32661
# 0
# 67969
# 0
# 56703
# 0
# 6986
# 0

# %%
filename1 = "./BTCV_Data/0826_affine_GT_6/1.nii.gz"
filename2 = "./BTCV_Data/gt_resize/40.nii.gz"
x1 = nib.load(filename1).get_fdata()
x1 = x1.astype(np.float32)
x2 = nib.load(filename2).get_fdata()
x2 = x2.astype(np.float32)    

def dice_coef_multilabel(y_true, y_pred, labels=13):
    w, h, d = y_true.shape
    label_interaction = []
    label_union = []
    total_dice = 0
    # print(y_true.shape)
    for m in range(0, labels+1):
        interact = 0
        gakgak = 0 
        for i in range(0, w):
            for j in range(0, h):
                for k in range(0, d):
                        if y_true[i][j][k] == m and y_pred[i][j][k] == m:
                            interact += 1
                        if y_true[i][j][k] == m:
                            gakgak += 1
                        if y_pred[i][j][k] == m:
                            gakgak += 1
        if interact != None:
            label_interaction.append(interact)
        else:
            label_interaction.append(0)
        if gakgak != None:
            label_union.append(gakgak)
        else:
            label_union.append(0)
        
        #print(label_interaction)
        
        dice = (label_interaction[m]*2) / label_union[m]
        total_dice += dice
        print("class: "+ str(m) + "    Dice: "+ str(dice))
        
    print("total_dice: " + str(total_dice / (labels+1)))

        
dice_coef_multilabel(x1, x2)
# Out:
# class: 0    Dice: 0.9701613399886906
# class: 1    Dice: 0.022011617242433508
# class: 2    Dice: 0.1679790026246719
# class: 3    Dice: 0.027010923535253226
# class: 4    Dice: 0.0
# class: 5    Dice: 0.09724473257698542
# class: 6    Dice: 0.4285953037519846
# class: 7    Dice: 0.3214102168773769
# class: 8    Dice: 0.06472019464720194
# class: 9    Dice: 0.21372549019607842
# class: 10    Dice: 0.034610630407911
# class: 11    Dice: 0.09801801801801802
# class: 12    Dice: 0.0
# class: 13    Dice: 0.0
# total_dice: 0.17467767641904325
